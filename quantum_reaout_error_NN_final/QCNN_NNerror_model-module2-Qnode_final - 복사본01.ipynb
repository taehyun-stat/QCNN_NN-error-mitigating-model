# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preparations" data-toc-modified-id="Preparations-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>Preparations</a></span><ul class="toc-item"><li><span><a href="#Adjusting-Jupyter's-display" data-toc-modified-id="Adjusting-Jupyter's-display-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Adjusting Jupyter's display</a></span></li><li><span><a href="#Creating-'Result'-folder" data-toc-modified-id="Creating-'Result'-folder-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Creating 'Result' folder</a></span></li></ul></li><li><span><a href="#Install-/-Loading-packages" data-toc-modified-id="Install-/-Loading-packages-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Install / Loading packages</a></span></li><li><span><a href="#Data-Preparation" data-toc-modified-id="Data-Preparation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Preparation</a></span><ul class="toc-item"><li><span><a href="#Module---1_data" data-toc-modified-id="Module---1_data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Module - 1_data</a></span></li><li><span><a href="#Let's-check-the-datasets-using-data_load_and_process" data-toc-modified-id="Let's-check-the-datasets-using-data_load_and_process-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Let's check the datasets using <code>data_load_and_process</code></a></span></li></ul></li><li><span><a href="#QCNN-circuits-represented-into-Qnode" data-toc-modified-id="QCNN-circuits-represented-into-Qnode-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>QCNN circuits represented into Qnode</a></span></li><li><span><a href="#CNN-and-QCNN-circuit-build" data-toc-modified-id="CNN-and-QCNN-circuit-build-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>CNN and QCNN circuit build</a></span><ul class="toc-item"><li><span><a href="#CNN-circuit" data-toc-modified-id="CNN-circuit-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>CNN circuit</a></span></li><li><span><a href="#QCNN-circuit" data-toc-modified-id="QCNN-circuit-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>QCNN circuit</a></span></li></ul></li><li><span><a href="#Qnode-example-from-PennyLane" data-toc-modified-id="Qnode-example-from-PennyLane-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Qnode example from PennyLane</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Defining-Qnode" data-toc-modified-id="Defining-Qnode-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Defining Qnode</a></span></li><li><span><a href="#Statevector-result-in-Pennylane" data-toc-modified-id="Statevector-result-in-Pennylane-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>Statevector result in Pennylane</a></span></li><li><span><a href="#Qnode-Example" data-toc-modified-id="Qnode-Example-5.0.3"><span class="toc-item-num">5.0.3&nbsp;&nbsp;</span>Qnode Example</a></span></li></ul></li></ul></li><li><span><a href="#QCNN---QNODE" data-toc-modified-id="QCNN---QNODE-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>QCNN - QNODE</a></span><ul class="toc-item"><li><span><a href="#Creating-devices---simulator-with-/-without-noise" data-toc-modified-id="Creating-devices---simulator-with-/-without-noise-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Creating devices - simulator with / without noise</a></span></li><li><span><a href="#Dataset---MNIST" data-toc-modified-id="Dataset---MNIST-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Dataset - MNIST</a></span></li><li><span><a href="#QCNN-circuits" data-toc-modified-id="QCNN-circuits-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>QCNN circuits</a></span><ul class="toc-item"><li><span><a href="#Circuit-specifications" data-toc-modified-id="Circuit-specifications-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Circuit specifications</a></span></li><li><span><a href="#Circuit-Optimization-/-Results" data-toc-modified-id="Circuit-Optimization-/-Results-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Circuit Optimization / Results</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Preparations

# %% [markdown]
# ## Adjusting Jupyter's display
# - You can increase the width of the display of the jupyter notebook by adjusting the HTML style.
#     - Adjust the width's percentage.
# - If it's not necessary, dont' execute the code.

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:65% !important; }</style>"))
# Out:
# <style>.container { width:65% !important; }</style>

# %% [markdown]
# ## Creating 'Result' folder
# - ["how to create folder in python"](https://www.codegrepper.com/code-examples/python/how+to+create+folder+in+python)

# %%
import os

newpath = 'Result'
if not os.path.exists(newpath):
    os.makedirs(newpath)

# %% [markdown]
# # Install / Loading packages

# %%
# !pip install pennylane
# !pip install tensorflow

# %% [markdown]
# # Data Preparation
# - 'MNIST' data is a dataset of 60,000, 28$\times$28 grayscale images of the 10 digits, along with a test set of 10,000 images.
# - Each pixel has grey scale value that ranges from 0 to 255.
# - More info can be found at the [MNIST homepage](http://yann.lecun.com/exdb/mnist/).
# - QCNN : https://github.com/takh04/QCNN/blob/main/README.md

# %%
# # Add directory path of the python-module files to import them.
# import sys
# # sys.path.insert(0,'C:/Users/THK/Desktop/qauntum_readout_error_NN/QCNN-main/Final_QCNN')
# # sys.path

# %%
# import sys
# import os

# sys.path.append(os.path.abspath('C:/Users/THK/Desktop/qauntum_readout_error_NN/QCNN_modules'))
# sys.path

# %% [markdown]
# To see if the directory path is added to the sys.path, check `sys.path`

# %% [markdown]
# ## Module - 1_data

# %%
# # Run modules
# %run QCNN_modules2/data.py

# %% [markdown]
# Function Descriptions:
# - `data_load_and_process(dataset, classes = [0, 1], feature_reduction = 'resize256', binary = True)`
#     - <u>dataset</u>: choose the dataset (**'mnist'** or **'fashion_mnist'**)
#     - <u>classes</u>: choose the type of y-classes (**'odd_even'**, **'>4'**, **[0, 1]**)
#     - <u>feature_reduction</u>: choose the method of dimension reduction with the number of features to be selected
#         - For Amplitude encoding     : **'resize256'**
#         - For Qubit encoding         : **'pca8'**, **'autoencoder8'**
#         - For Dense qubit encoding   : **'pca16-1', 'pca16-2', 'pca16-3', 'pca16-4', 'pca16-compact'**, **'autoencoder16-1', 'autoencoder16-2', 'autoencoder16-3', 'autoencoder16-4', 'autoencoder16-compact'**
#         - For Hybrid direct encoding : **'pca32-1', 'pca32-2', 'pca32-3', 'pca32-4'**, **'autoencoder32-1', 'autoencoder32-2', 'autoencoder32-3', 'autoencoder32-4'**
#         - For Hybrid angle encoding  : **'pca30-1', 'pca30-2', 'pca30-3', 'pca30-4'**, **'autoencoder30-1', 'autoencoder30-2', 'autoencoder30-3', 'autoencoder30-4'**
#         - For extra                  : **'pca12-1', 'pca12-2', 'pca12-3', 'pca12-4'**, **'autoencoder12-1', 'autoencoder12-2', 'autoencoder12-3', 'autoencoder12-4'**
#     - <u>binary</u>: If 'True', dataset splits 'y classes' into +1, and -1.(**'True'**, or **'False'**). When using 'cross entropy loss', use binary=**False**. If using 'mse_loss' use binary=**True**.
#
#
# - This function returns normalized, dimensions reduced datasets ready to be used to train the model: X_train, X_test, Y_train, Y_test

# %% [markdown]
# ## Let's check the datasets using `data_load_and_process`
# - Let's upload the dataset using `data_load_and_process` and check its dimensions, size, and the number of features which we will be using.

# %%
# Generate datasets
dataset_name = 'mnist'
feature_reduction_method = 'pca8'

# Get 'mnist' with {0, 1} classes
X_train, X_test, Y_train, Y_test = data_load_and_process(dataset=dataset_name,
                                                         classes=[0, 1],
                                                         feature_reduction=feature_reduction_method,
                                                         binary=True)

# %%
# Dimensions of the generated datasets
print('Dimensions of `' + str(dataset_name) + '` Train / Test data')
print('Feature reduction method: `' + str(feature_reduction_method) + '`')
print('Name of the dataset (num_obs, num_features):')
print('  X_train: ' + str(X_train.shape))
print('  Y_train: ' + str(len(Y_train)))
print('  X_test : ' + str(X_test.shape))
print('  Y_test : ' + str(len(Y_test)))
# Out:
# Dimensions of `mnist` Train / Test data
# Feature reduction method: `pca8`
# Name of the dataset (num_obs, num_features):
#   X_train: (12665, 8)
#   Y_train: 12665
#   X_test : (2115, 8)
#   Y_test : 2115

# %%
Y_train[0:4]
# Out:
# [1, -1, -1, -1]

# %% [markdown]
# # QCNN circuits represented into Qnode

# %%
# import numpy as np
# import math
# import tensorflow as tf
# from sklearn.decomposition import PCA
# from tensorflow.keras.models import Model
# from tensorflow.keras import layers, losses
# import torch
# import torch.nn as nn

import time

# %% [markdown]
# # CNN and QCNN circuit build

# %% [markdown]
# ## CNN circuit
# - It builds classcial CNN circuit with same datasets given by `data_load_and_process`
# - py file optimizes and benchmarks of the CNN model when it is executed.

# %%
# # Run module
# %run QCNN_modules2/CNN.py

# %% [markdown]
# ## QCNN circuit

# %% [markdown]
# - We will making QCNN circuits based on the given 'Data encoding' and 'Ansatz'.
# - Here are some informations about the building blocks of the QCNN circuits.
#
# ![QCNN_boundary](img/QCNN_boundary.png)

# %% [markdown]
# - Data encoding(5): `embedding_type`
#     - Amplitude encoding     : **Amplitude**
#     - Qubit encoding         : **Angle**
#     - Dense qubit encoding   : **Angle-compact**
#     - Hybrid Direct encoding : **'Amplitude-Hybrid2-1, 2, 3, 4**, **Amplitude-Hybrid4-1, 2, 3, 4**
#     - Hybrid Angle encoding  : **'Angular-Hybrid2-1, 2, 3, 4**, **Angular-Hybrid4-1, 2, 3, 4**
#         - At Hybrid encodings, '2' is for one block per 2 qubits, resulting 4 blocks on 8 qubits, and '4' is for one block per 4 qubints, resulting 2 blocks on 8 qubits.

# %% [markdown]
# - Convolutional filter(9): `U`
# - Pooling layer(2): Default for the pooling is 'yes'.
#     - #1  : **U_TTN**
#     - #2  : **U_9**
#     - #3  : **U_15**
#     - #4  : **U_13**
#     - #5  : **U_14**
#     - #6  : **U_SO4**
#     - #7  : **U_5**
#     - #8  : **U_6**
#     - #9a : **U_SU4**
#     - #9b : **U_SU4_no_pooling**
#
# ![convolutional_circuits](img/convolutional_circuits.png)
#
# ![pooling_layer](img/pooling_layer.png)

# %% [markdown]
# - Circuit boundary conditions(2):
#     - The default of the boundary condition of the QCNN is 'yes'.
#     - No boundary condition with #2  :**U_9_1D**
#     - No boundary condition with #9b :**U_SU4_1D**
#
# ![QCNN_no_boundary](img/QCNN_no_boundary.png)

# %% [markdown]
# - Cost Function(2+1): `cost_fn`
#     - Cross entrophy: **cross_entropy**
#     - Mean squared error: **mse**
#     - Means squared error with penalty term: **square_loss_lambda**

# %% [markdown]
# - The total number of features in Data Encoding steps with 8-qubits QCNN model are given below.
#     - Amplitude encoding (AE)      : $2^{8}=256$
#     - Qubit encoding               : $8$
#     - Dense qubit encoding         : $8 \times 2=16$
#     - Hybrid direct encoding (HDE) : $2^{8\div2} \times 2=32$
#     - Hybrid angle encoding (HAE)  : $(2^{8\div2}-1) \times 2=30$
#
#
# - The total number of parameters used in the quantum circuits are given below.
#     - Convolutional Filter(=`U_params`) + Pooling Layer $\times$ (3 layers) = total number of parameters
#         - #1 : $(2 + 2) \times 3 = 12$
#         - #2 : $(2 + 2) \times 3 = 12$
#         - #3 : $(4 + 2) \times 3 = 18$
#         - #4 : $(6 + 2) \times 3 = 24$
#         - #5 : $(6 + 2) \times 3 = 24$
#         - #6 : $(6 + 2) \times 3 = 24$
#         - #7 : $(10 + 2) \times 3 = 36$
#         - #8 : $(10 + 2) \times 3 = 36$
#         - #9a: $(15 + 2) \times 3 = 51$
#         - #9b: $(15 + 0) \times 3 = 45$

# %% [markdown]
# - Function Descriptions:
#     - Three functions below are embedded in `QCNN` function:
#         - `QCNN_structure(U, params, U_params)` : #1 ~ #9a
#         - `QCNN_structure_without_pooling(U, params, U_params)` : #9b
#         - `QCNN_1D_circuit(U, params, U_params)` : #2, #9b without boundary conditions
#     - `QCNN(X, params, U, U_params, embedding_type='Amplitude', cost_fn='cross_entropy', measure_axis='Z')` :
#         - X : **X_train**
#         - params: parameters of the quantum circuit
#         - U : **U_TTN**, **U_9**, **U_15**, **U_13**, **U_14**, **U_SO4**, **U_5**, **U_6**, **U_SU4**, **U_SU4_no_pooling**, **U_9_1D**, **U_SU4_1D**
#         - U_params : The number of parameters in a convolutional filter which depends on the choice of the convolutional filter.
#             - **2**, **2**, **4**, **6**, **6**, **6**, **10**, **10**, **15**, **15**
#         - embedding_type: Choose the data encoding depending on the order of putting features
#             - **Amplitude**, **Angle**, **Angle-compact**, **Amplitude-Hybrid2-1, 2, 3, 4**, **Amplitude-Hybrid4-1, 2, 3, 4**, **Angular-Hybrid2-1, 2, 3, 4**, **Angular-Hybrid4-1, 2, 3, 4**
#         - cost_fn: **cross_entropy**, **mse**
#         - measure_axis: measuring the final state in Z-axis(computational basis), Y-axis(circular basis), X-axis(Hadamard basis)
#             - **'Z'**, **'Y'**, **'X'**,

# %% [markdown]
# # Qnode example from PennyLane

# %% [markdown]
# - [Turning quantum nodes into Keras Layers](https://pennylane.ai/qml/demos/tutorial_qnn_module_tf.html)
# - [qml.probs](https://docs.pennylane.ai/en/stable/code/api/pennylane.probs.html)
# - [qml.qnn.KerasLayer](https://docs.pennylane.ai/en/stable/code/api/pennylane.qnn.KerasLayer.html)
# - [qml.qnn.TorchLayer](https://docs.pennylane.ai/en/stable/code/api/pennylane.qnn.TorchLayer.html)

# %%
import tensorflow as tf

tf.keras.backend.set_floatx('float64')

layer_1 = tf.keras.layers.Dense(2)
layer_2 = tf.keras.layers.Dense(2, activation="softmax")

model = tf.keras.Sequential([layer_1, layer_2])
model.compile(loss="mae")

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons

# Set random seeds
np.random.seed(42)
tf.random.set_seed(42)

X, y = make_moons(n_samples=200, noise=0.1)
y_hot = tf.keras.utils.to_categorical(
    y, num_classes=2)  # one-hot encoded labels

c = ["#1f77b4" if y_ == 0 else "#ff7f0e" for y_ in y]  # colours for each class
plt.axis("off")
plt.scatter(X[:, 0], X[:, 1], c=c)
plt.show()

# %% [markdown]
# ### Defining Qnode

# %%
import pennylane as qml

n_qubits = 2
dev = qml.device("default.qubit", wires=n_qubits)


@qml.qnode(dev)
def qnode(inputs, weights):
    qml.AngleEmbedding(inputs, wires=range(n_qubits))
    qml.BasicEntanglerLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# %%
n_layers = 6
weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
type(weight_shapes)
# Out:
# dict

# %%
qlayer = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=n_qubits)

# %%
clayer_1 = tf.keras.layers.Dense(2)
clayer_2 = tf.keras.layers.Dense(2, activation="softmax")
model = tf.keras.models.Sequential([clayer_1, qlayer, clayer_2])

# %%
opt = tf.keras.optimizers.SGD(learning_rate=0.2)
model.compile(opt, loss="mae", metrics=["accuracy"])

fitting = model.fit(X, y_hot, epochs=5, batch_size=5,
                    validation_split=0.25, verbose=2)
# Out:
# Epoch 1/5
# 30/30 - 7s - loss: 0.4695 - accuracy: 0.6800 - val_loss: 0.3833 - val_accuracy: 0.7800 - 7s/epoch - 235ms/step
# Epoch 2/5
# 30/30 - 8s - loss: 0.3411 - accuracy: 0.7333 - val_loss: 0.2726 - val_accuracy: 0.7400 - 8s/epoch - 267ms/step
# Epoch 3/5
# 30/30 - 8s - loss: 0.2603 - accuracy: 0.7800 - val_loss: 0.2240 - val_accuracy: 0.8000 - 8s/epoch - 275ms/step
# Epoch 4/5
# 30/30 - 9s - loss: 0.2260 - accuracy: 0.7933 - val_loss: 0.2013 - val_accuracy: 0.8200 - 9s/epoch - 296ms/step
# Epoch 5/5
# 30/30 - 9s - loss: 0.1956 - accuracy: 0.8400 - val_loss: 0.1844 - val_accuracy: 0.8200 - 9s/epoch - 293ms/step

# %% [markdown]
# ### Statevector result in Pennylane

# %%
dev = qml.device('default.qubit', wires=2)


@qml.qnode(dev)
def example_circuit():
    qml.QubitStateVector(np.array([1, 0, 0, 0]), wires=range(2))
    return qml.state()

# %%
cir_result = example_circuit()

print(type(cir_result))
print(cir_result)
# Out:
# <class 'pennylane.numpy.tensor.tensor'>
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
cir_result[0]
# Out:
# tensor(1.+0.j, requires_grad=True)

# %%
type(example_circuit())
# Out:
# pennylane.numpy.tensor.tensor

# %% [markdown]
# ### Qnode Example

# %%
n_qubits = 4
dev = qml.device("default.qubit", wires=n_qubits)


@qml.qnode(dev)
def qnode(inputs, weights_0, weight_1):
    qml.RX(inputs[0], wires=0)
    qml.RX(inputs[1], wires=1)

    qml.Rot(weights_0, wires=0)
    qml.RY(weight_1, wires=1)
    qml.Rot(weights_0, wires=0)
    qml.RY(weight_1, wires=1)
    qml.Rot(weights_0, wires=0)
    qml.RY(weight_1, wires=1)
    qml.CNOT(wires=[0, 1])
    return qml.expval(qml.PauliZ(0)), qml.expval(qml.PauliZ(1))

# %%
weight_shapes = {"weights_0": 3, "weight_1": 1}
qlayer = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=2)

# %%
clayer = tf.keras.layers.Dense(2)
model = tf.keras.models.Sequential([qlayer, clayer])

# %%
model

# %%
weight_shapes
# Out:
# {'weights_0': 3, 'weight_1': 1}

# %%
model.summary
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x0000023C32A6E4C0>>

# %% [markdown]
# # QCNN - QNODE

# %% [markdown]
# ## Creating devices - simulator with / without noise

# %% [markdown]
# - Number of qubits

# %%
import pennylane as qml
from pennylane import numpy as np

n_qubits = 8

# %% [markdown]
# - Create devices with different readout error probabilities

# %%
dev_noisy0 = qml.device("default.qubit", wires=n_qubits)
dev_noisy1 = qml.device("default.mixed", wires=n_qubits, readout_prob=0.0001)
dev_noisy2 = qml.device("default.mixed", wires=n_qubits, readout_prob=0.001)
dev_noisy3 = qml.device("default.mixed", wires=n_qubits, readout_prob=0.01)
dev_noisy4 = qml.device("default.mixed", wires=n_qubits, readout_prob=0.1)

dev_list = [dev_noisy0, dev_noisy1, dev_noisy2, dev_noisy3, dev_noisy4]

# %% [markdown]
# ## Dataset - MNIST

# %%
# MNIST datasets
dataset_name = 'mnist'
feature_reduction_method = 'resize256'


X_train, X_test, Y_train, Y_test = data_load_and_process(dataset=dataset_name,
                                                         classes=[0, 1],
                                                         feature_reduction=feature_reduction_method,
                                                         binary=True)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (12665, 256)
# (2115, 256)

# %%
Y_train.count(-1)
# Out:
# 6742

# %%
print("# of 0s in train: ", Y_train.count(-1))
print("# of 1s in train: ", Y_train.count(1))

print("# of 0s in test: ", Y_test.count(-1))
print("# of 1s in test: ", Y_test.count(1))
# Out:
# # of 0s in train:  6742
# # of 1s in train:  5923
# # of 0s in test:  1135
# # of 1s in test:  980

# %%
from tensorflow.keras.utils import to_categorical


Y_train_label = (np.array(Y_train)+1)/2
Y_train_onehot = to_categorical(Y_train_label)

Y_test_label = (np.array(Y_test)+1)/2
Y_test_onehot = to_categorical(Y_test_label)

# %% [markdown]
# ## QCNN circuits

# %% [markdown]
# ### Circuit specifications

# %%
# Circuit training hyper parameters of the optimizer: NesterovMomentumOptimizer
# steps = 200
# learning_rate = 0.01
# batch_size = 25

dataset_name = 'mnist'
Unitaries_list = ['U_TTN']
# Unitaries_list = ['U_TTN', 'U_9', 'U_15', 'U_13', 'U_14', 'U_SO4', 'U_5', 'U_6', 'U_SU4', 'U_SU4_no_pooling']
U_num_params_list = [2]
# U_num_params_list = [2, 2, 4, 6, 6, 6, 10, 10, 15, 15]
Encodings_list = ['resize256']
# Encodings_list = ['resize256', 'pca8', 'autoencoder8', 'pca16-1', 'autoencoder16-1', 'pca32-1', 'autoencoder32-1', 'pca30-1', 'autoencoder30-1']

circuit_type = 'QCNN'
# ['cross_entropy', 'mse', 'mse_lambda', 'classify_lambda', 'classify_lambda2']
cost_fn_type = 'mse'
lambda_value = 0.05
lambd_decs = False
num_obs_ploting = None

# %%
def Encoding_to_Embedding(Encoding):
    # Amplitude Embedding / Angle Embedding
    if Encoding == 'resize256':
        Embedding = 'Amplitude'
    elif Encoding == 'pca8':
        Embedding = 'Angle'
    elif Encoding == 'autoencoder8':
        Embedding = 'Angle'

    # Amplitude Hybrid Embedding
    # 4 qubit block
    elif Encoding == 'pca32-1':
        Embedding = 'Amplitude-Hybrid4-1'
    elif Encoding == 'autoencoder32-1':
        Embedding = 'Amplitude-Hybrid4-1'

    elif Encoding == 'pca32-2':
        Embedding = 'Amplitude-Hybrid4-2'
    elif Encoding == 'autoencoder32-2':
        Embedding = 'Amplitude-Hybrid4-2'

    elif Encoding == 'pca32-3':
        Embedding = 'Amplitude-Hybrid4-3'
    elif Encoding == 'autoencoder32-3':
        Embedding = 'Amplitude-Hybrid4-3'

    elif Encoding == 'pca32-4':
        Embedding = 'Amplitude-Hybrid4-4'
    elif Encoding == 'autoencoder32-4':
        Embedding = 'Amplitude-Hybrid4-4'

    # 2 qubit block
    elif Encoding == 'pca16-1':
        Embedding = 'Amplitude-Hybrid2-1'
    elif Encoding == 'autoencoder16-1':
        Embedding = 'Amplitude-Hybrid2-1'

    elif Encoding == 'pca16-2':
        Embedding = 'Amplitude-Hybrid2-2'
    elif Encoding == 'autoencoder16-2':
        Embedding = 'Amplitude-Hybrid2-2'

    elif Encoding == 'pca16-3':
        Embedding = 'Amplitude-Hybrid2-3'
    elif Encoding == 'autoencoder16-3':
        Embedding = 'Amplitude-Hybrid2-3'

    elif Encoding == 'pca16-4':
        Embedding = 'Amplitude-Hybrid2-4'
    elif Encoding == 'autoencoder16-4':
        Embedding = 'Amplitude-Hybrid2-4'

    # Angular HybridEmbedding
    # 4 qubit block
    elif Encoding == 'pca30-1':
        Embedding = 'Angular-Hybrid4-1'
    elif Encoding == 'autoencoder30-1':
        Embedding = 'Angular-Hybrid4-1'

    elif Encoding == 'pca30-2':
        Embedding = 'Angular-Hybrid4-2'
    elif Encoding == 'autoencoder30-2':
        Embedding = 'Angular-Hybrid4-2'

    elif Encoding == 'pca30-3':
        Embedding = 'Angular-Hybrid4-3'
    elif Encoding == 'autoencoder30-3':
        Embedding = 'Angular-Hybrid4-3'

    elif Encoding == 'pca30-4':
        Embedding = 'Angular-Hybrid4-4'
    elif Encoding == 'autoencoder30-4':
        Embedding = 'Angular-Hybrid4-4'

    # 2 qubit block
    elif Encoding == 'pca12-1':
        Embedding = 'Angular-Hybrid2-1'
    elif Encoding == 'autoencoder12-1':
        Embedding = 'Angular-Hybrid2-1'

    elif Encoding == 'pca12-2':
        Embedding = 'Angular-Hybrid2-2'
    elif Encoding == 'autoencoder12-2':
        Embedding = 'Angular-Hybrid2-2'

    elif Encoding == 'pca12-3':
        Embedding = 'Angular-Hybrid2-3'
    elif Encoding == 'autoencoder12-3':
        Embedding = 'Angular-Hybrid2-3'

    elif Encoding == 'pca12-4':
        Embedding = 'Angular-Hybrid2-4'
    elif Encoding == 'autoencoder12-4':
        Embedding = 'Angular-Hybrid2-4'

    # Two Gates Compact Encoding
    elif Encoding == 'pca16-compact':
        Embedding = 'Angle-compact'
    elif Encoding == 'autoencoder16-compact':
        Embedding = 'Angle-compact'
    return Embedding

# %%
Embedding = Encoding_to_Embedding(Encodings_list[0])
Embedding
# Out:
# 'Amplitude'

# %%
# Run modules
# %run QCNN_modules2/Angular_hybrid.py
# %run QCNN_modules2/embedding.py
# %run QCNN_modules2/unitary.py

# %run QCNN_modules2/QCNN_circuit.py

# %%
# QCNN circuit build with data encoding, convolutional layers, pooling layers, and measurement
def QCNN_circuit_node(inputs, params):

    # Data Embedding
    data_embedding(inputs, embedding_type=Embedding)

    # Quantum Convolutional Neural Network
    # Convolutional Layer #1
    if U == "U_TTN":
        # Layer 1 - Convolution
        qml.RY(params[0], wires=7)
        qml.RY(params[1], wires=0)
        qml.CNOT(wires=[7, 0])
        for i in range(0, 8, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CNOT(wires=[i, i+1])
        for i in range(1, 7, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CNOT(wires=[i, i+1])

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[6], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[7], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.RY(params[2], wires=6)
        qml.RY(params[3], wires=0)
        qml.CNOT(wires=[6, 0])
        qml.RY(params[2], wires=0)
        qml.RY(params[3], wires=2)
        qml.CNOT(wires=[0, 2])
        qml.RY(params[2], wires=4)
        qml.RY(params[3], wires=6)
        qml.CNOT(wires=[4, 6])
        qml.RY(params[2], wires=2)
        qml.RY(params[3], wires=4)
        qml.CNOT(wires=[2, 4])

        # Layer 2 - Pooling
        qml.CRZ(params[8], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[9], wires=[2, 0])
        qml.CRZ(params[8], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[9], wires=[6, 4])

        # Layer 3 - Convolution
        qml.RY(params[4], wires=4)
        qml.RY(params[5], wires=0)
        qml.CNOT(wires=[4, 0])

        # Layer 3 - Pooling
        qml.CRZ(params[10], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[11], wires=[4, 0])

    # Convolutional Layer #2
    elif U == "U_9":
        # Layer 1 - Convolution
        qml.Hadamard(wires=7)
        qml.Hadamard(wires=0)
        qml.CZ(wires=[7, 0])
        qml.RX(params[0], wires=7)
        qml.RX(params[1], wires=0)
        for i in range(0, 8, 2):
            qml.Hadamard(wires=i)
            qml.Hadamard(wires=i+1)
            qml.CZ(wires=[i, i+1])
            qml.RX(params[0], wires=i)
            qml.RX(params[1], wires=i+1)
        for i in range(1, 7, 2):
            qml.Hadamard(wires=i)
            qml.Hadamard(wires=i+1)
            qml.CZ(wires=[i, i+1])
            qml.RX(params[0], wires=i)
            qml.RX(params[1], wires=i+1)

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[6], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[7], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.Hadamard(wires=6)
        qml.Hadamard(wires=0)
        qml.CZ(wires=[6, 0])
        qml.RX(params[2], wires=6)
        qml.RX(params[3], wires=0)
        qml.Hadamard(wires=0)
        qml.Hadamard(wires=2)
        qml.CZ(wires=[0, 2])
        qml.RX(params[2], wires=0)
        qml.RX(params[3], wires=2)
        qml.Hadamard(wires=4)
        qml.Hadamard(wires=6)
        qml.CZ(wires=[4, 6])
        qml.RX(params[2], wires=4)
        qml.RX(params[3], wires=6)
        qml.Hadamard(wires=2)
        qml.Hadamard(wires=4)
        qml.CZ(wires=[2, 4])
        qml.RX(params[2], wires=2)
        qml.RX(params[3], wires=4)

        # Layer 2 - Pooling
        qml.CRZ(params[8], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[9], wires=[2, 0])
        qml.CRZ(params[8], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[9], wires=[6, 4])

        # Layer 3 - Convolution
        qml.Hadamard(wires=4)
        qml.Hadamard(wires=0)
        qml.CZ(wires=[4, 0])
        qml.RX(params[4], wires=4)
        qml.RX(params[5], wires=0)

        # Layer 3 - Pooling
        qml.CRZ(params[10], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[11], wires=[4, 0])

    # Convolutional Layer #3
    elif U == "U_15":
        # Layer 1 - Convolution
        qml.RY(params[0], wires=7)
        qml.RY(params[1], wires=0)
        qml.CNOT(wires=[0, 7])
        qml.RY(params[2], wires=7)
        qml.RY(params[3], wires=0)
        qml.CNOT(wires=[7, 0])
        for i in range(0, 8, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CNOT(wires=[i+1, i])
            qml.RY(params[2], wires=i)
            qml.RY(params[3], wires=i+1)
            qml.CNOT(wires=[i, i+1])
        for i in range(1, 7, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CNOT(wires=[i+1, i])
            qml.RY(params[2], wires=i)
            qml.RY(params[3], wires=i+1)
            qml.CNOT(wires=[i, i+1])

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[12], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[13], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.RY(params[4], wires=6)
        qml.RY(params[5], wires=0)
        qml.CNOT(wires=[6, 0])
        qml.RY(params[6], wires=6)
        qml.RY(params[7], wires=0)
        qml.CNOT(wires=[6, 0])
        qml.RY(params[4], wires=0)
        qml.RY(params[5], wires=2)
        qml.CNOT(wires=[0, 2])
        qml.RY(params[6], wires=0)
        qml.RY(params[7], wires=2)
        qml.CNOT(wires=[0, 2])
        qml.RY(params[4], wires=4)
        qml.RY(params[5], wires=6)
        qml.CNOT(wires=[4, 6])
        qml.RY(params[6], wires=4)
        qml.RY(params[7], wires=6)
        qml.CNOT(wires=[4, 6])
        qml.RY(params[4], wires=2)
        qml.RY(params[5], wires=4)
        qml.CNOT(wires=[2, 4])
        qml.RY(params[6], wires=2)
        qml.RY(params[7], wires=4)
        qml.CNOT(wires=[2, 4])

        # Layer 2 - Pooling
        qml.CRZ(params[14], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[15], wires=[2, 0])
        qml.CRZ(params[14], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[15], wires=[6, 4])

        # Layer 3 - Convolution
        qml.RY(params[8], wires=4)
        qml.RY(params[9], wires=0)
        qml.CNOT(wires=[4, 0])
        qml.RY(params[10], wires=4)
        qml.RY(params[11], wires=0)
        qml.CNOT(wires=[4, 0])

        # Layer 3 - Pooling
        qml.CRZ(params[16], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[17], wires=[4, 0])

    # Convolutional Layer #4
    elif U == "U_13":
        # Layer 1 - Convolution
        qml.RY(params[0], wires=7)
        qml.RY(params[1], wires=0)
        qml.CRZ(params[2], wires=[0, 7])
        qml.RY(params[3], wires=7)
        qml.RY(params[4], wires=0)
        qml.CRZ(params[5], wires=[7, 0])
        for i in range(0, 8, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CRZ(params[2], wires=[i+1, i])
            qml.RY(params[3], wires=i)
            qml.RY(params[4], wires=i+1)
            qml.CRZ(params[5], wires=[i, i+1])
        for i in range(1, 7, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CRZ(params[2], wires=[i+1, i])
            qml.RY(params[3], wires=i)
            qml.RY(params[4], wires=i+1)
            qml.CRZ(params[5], wires=[i, i+1])

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[18], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[19], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.RY(params[6], wires=6)
        qml.RY(params[7], wires=0)
        qml.CRZ(params[8], wires=[6, 0])
        qml.RY(params[9], wires=6)
        qml.RY(params[10], wires=0)
        qml.CRZ(params[11], wires=[6, 0])
        qml.RY(params[6], wires=0)
        qml.RY(params[7], wires=2)
        qml.CRZ(params[8], wires=[0, 2])
        qml.RY(params[9], wires=0)
        qml.RY(params[10], wires=2)
        qml.CRZ(params[11], wires=[0, 2])
        qml.RY(params[6], wires=4)
        qml.RY(params[7], wires=6)
        qml.CRZ(params[8], wires=[4, 6])
        qml.RY(params[9], wires=4)
        qml.RY(params[10], wires=6)
        qml.CRZ(params[11], wires=[4, 6])
        qml.RY(params[6], wires=2)
        qml.RY(params[7], wires=4)
        qml.CRZ(params[8], wires=[2, 4])
        qml.RY(params[9], wires=2)
        qml.RY(params[10], wires=4)
        qml.CRZ(params[11], wires=[2, 4])

        # Layer 2 - Pooling
        qml.CRZ(params[20], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[21], wires=[2, 0])
        qml.CRZ(params[20], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[21], wires=[6, 4])

        # Layer 3 - Convolution
        qml.RY(params[12], wires=4)
        qml.RY(params[13], wires=0)
        qml.CRZ(params[14], wires=[4, 0])
        qml.RY(params[15], wires=4)
        qml.RY(params[16], wires=0)
        qml.CRZ(params[17], wires=[4, 0])

        # Layer 3 - Pooling
        qml.CRZ(params[22], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[23], wires=[4, 0])

    # Convolutional Layer #5
    elif U == "U_14":
        # Layer 1 - Convolution
        qml.RY(params[0], wires=7)
        qml.RY(params[1], wires=0)
        qml.CRX(params[2], wires=[0, 7])
        qml.RY(params[3], wires=7)
        qml.RY(params[4], wires=0)
        qml.CRX(params[5], wires=[7, 0])
        for i in range(0, 8, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CRX(params[2], wires=[i+1, i])
            qml.RY(params[3], wires=i)
            qml.RY(params[4], wires=i+1)
            qml.CRX(params[5], wires=[i, i+1])
        for i in range(1, 7, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CRX(params[2], wires=[i+1, i])
            qml.RY(params[3], wires=i)
            qml.RY(params[4], wires=i+1)
            qml.CRX(params[5], wires=[i, i+1])

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[18], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[19], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.RY(params[6], wires=6)
        qml.RY(params[7], wires=0)
        qml.CRX(params[8], wires=[0, 6])
        qml.RY(params[9], wires=6)
        qml.RY(params[10], wires=0)
        qml.CRX(params[11], wires=[6, 0])
        qml.RY(params[6], wires=0)
        qml.RY(params[7], wires=2)
        qml.CRX(params[8], wires=[2, 0])
        qml.RY(params[9], wires=0)
        qml.RY(params[10], wires=2)
        qml.CRX(params[11], wires=[0, 2])
        qml.RY(params[6], wires=4)
        qml.RY(params[7], wires=6)
        qml.CRX(params[8], wires=[6, 4])
        qml.RY(params[9], wires=4)
        qml.RY(params[10], wires=6)
        qml.CRX(params[11], wires=[4, 6])
        qml.RY(params[6], wires=2)
        qml.RY(params[7], wires=4)
        qml.CRX(params[8], wires=[4, 2])
        qml.RY(params[9], wires=2)
        qml.RY(params[10], wires=4)
        qml.CRX(params[11], wires=[2, 4])

        # Layer 2 - Pooling
        qml.CRZ(params[20], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[21], wires=[2, 0])
        qml.CRZ(params[20], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[21], wires=[6, 4])

        # Layer 3 - Convolution
        qml.RY(params[12], wires=4)
        qml.RY(params[13], wires=0)
        qml.CRX(params[14], wires=[0, 4])
        qml.RY(params[15], wires=4)
        qml.RY(params[16], wires=0)
        qml.CRX(params[17], wires=[4, 0])

        # Layer 3 - Pooling
        qml.CRZ(params[22], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[23], wires=[4, 0])

    # Convolutional Layer #6
    elif U == "U_SO4":
        # Layer 1 - Convolution
        qml.RY(params[0], wires=7)
        qml.RY(params[1], wires=0)
        qml.CNOT(wires=[7, 0])
        qml.RY(params[2], wires=7)
        qml.RY(params[3], wires=0)
        qml.CNOT(wires=[7, 0])
        qml.RY(params[4], wires=7)
        qml.RY(params[5], wires=0)
        for i in range(0, 8, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CNOT(wires=[i, i+1])
            qml.RY(params[2], wires=i)
            qml.RY(params[3], wires=i+1)
            qml.CNOT(wires=[i, i+1])
            qml.RY(params[4], wires=i)
            qml.RY(params[5], wires=i+1)
        for i in range(1, 7, 2):
            qml.RY(params[0], wires=i)
            qml.RY(params[1], wires=i+1)
            qml.CNOT(wires=[i, i+1])
            qml.RY(params[2], wires=i)
            qml.RY(params[3], wires=i+1)
            qml.CNOT(wires=[i, i+1])
            qml.RY(params[4], wires=i)
            qml.RY(params[5], wires=i+1)

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[18], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[19], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.RY(params[6], wires=6)
        qml.RY(params[7], wires=0)
        qml.CNOT(wires=[6, 0])
        qml.RY(params[8], wires=6)
        qml.RY(params[9], wires=0)
        qml.CNOT(wires=[6, 0])
        qml.RY(params[10], wires=6)
        qml.RY(params[11], wires=0)
        qml.RY(params[6], wires=0)
        qml.RY(params[7], wires=2)
        qml.CNOT(wires=[0, 2])
        qml.RY(params[8], wires=0)
        qml.RY(params[9], wires=2)
        qml.CNOT(wires=[0, 2])
        qml.RY(params[10], wires=0)
        qml.RY(params[11], wires=2)
        qml.RY(params[6], wires=4)
        qml.RY(params[7], wires=6)
        qml.CNOT(wires=[4, 6])
        qml.RY(params[8], wires=4)
        qml.RY(params[9], wires=6)
        qml.CNOT(wires=[4, 6])
        qml.RY(params[10], wires=4)
        qml.RY(params[11], wires=6)
        qml.RY(params[6], wires=2)
        qml.RY(params[7], wires=4)
        qml.CNOT(wires=[2, 4])
        qml.RY(params[8], wires=2)
        qml.RY(params[9], wires=4)
        qml.CNOT(wires=[2, 4])
        qml.RY(params[10], wires=2)
        qml.RY(params[11], wires=4)

        # Layer 2 - Pooling
        qml.CRZ(params[20], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[21], wires=[2, 0])
        qml.CRZ(params[20], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[21], wires=[6, 4])

        # Layer 3 - Convolution
        qml.RY(params[12], wires=4)
        qml.RY(params[13], wires=0)
        qml.CNOT(wires=[4, 0])
        qml.RY(params[14], wires=4)
        qml.RY(params[15], wires=0)
        qml.CNOT(wires=[4, 0])
        qml.RY(params[16], wires=4)
        qml.RY(params[17], wires=0)

        # Layer 3 - Pooling
        qml.CRZ(params[22], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[23], wires=[4, 0])

    # Convolutional Layer #7
    elif U == "U_5":
        # Layer 1 - Convolution
        qml.RX(params[0], wires=7)
        qml.RX(params[1], wires=0)
        qml.RZ(params[2], wires=7)
        qml.RZ(params[3], wires=0)
        qml.CRZ(params[4], wires=[0, 7])
        qml.CRZ(params[5], wires=[7, 0])
        qml.RX(params[6], wires=7)
        qml.RX(params[7], wires=0)
        qml.RZ(params[8], wires=7)
        qml.RZ(params[9], wires=0)
        for i in range(0, 8, 2):
            qml.RX(params[0], wires=i)
            qml.RX(params[1], wires=i+1)
            qml.RZ(params[2], wires=i)
            qml.RZ(params[3], wires=i+1)
            qml.CRZ(params[4], wires=[i+1, i])
            qml.CRZ(params[5], wires=[i, i+1])
            qml.RX(params[6], wires=i)
            qml.RX(params[7], wires=i+1)
            qml.RZ(params[8], wires=i)
            qml.RZ(params[9], wires=i+1)
        for i in range(1, 7, 2):
            qml.RX(params[0], wires=i)
            qml.RX(params[1], wires=i+1)
            qml.RZ(params[2], wires=i)
            qml.RZ(params[3], wires=i+1)
            qml.CRZ(params[4], wires=[i+1, i])
            qml.CRZ(params[5], wires=[i, i+1])
            qml.RX(params[6], wires=i)
            qml.RX(params[7], wires=i+1)
            qml.RZ(params[8], wires=i)
            qml.RZ(params[9], wires=i+1)

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[30], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[31], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.RX(params[10], wires=6)
        qml.RX(params[11], wires=0)
        qml.RZ(params[12], wires=6)
        qml.RZ(params[13], wires=0)
        qml.CRZ(params[14], wires=[0, 6])
        qml.CRZ(params[15], wires=[6, 0])
        qml.RX(params[16], wires=6)
        qml.RX(params[17], wires=0)
        qml.RZ(params[18], wires=6)
        qml.RZ(params[19], wires=0)
        qml.RX(params[10], wires=0)
        qml.RX(params[11], wires=2)
        qml.RZ(params[12], wires=0)
        qml.RZ(params[13], wires=2)
        qml.CRZ(params[14], wires=[2, 0])
        qml.CRZ(params[15], wires=[0, 2])
        qml.RX(params[16], wires=0)
        qml.RX(params[17], wires=2)
        qml.RZ(params[18], wires=0)
        qml.RZ(params[19], wires=2)
        qml.RX(params[10], wires=4)
        qml.RX(params[11], wires=6)
        qml.RZ(params[12], wires=4)
        qml.RZ(params[13], wires=6)
        qml.CRZ(params[14], wires=[6, 4])
        qml.CRZ(params[15], wires=[4, 6])
        qml.RX(params[16], wires=4)
        qml.RX(params[17], wires=6)
        qml.RZ(params[18], wires=4)
        qml.RZ(params[19], wires=6)
        qml.RX(params[10], wires=2)
        qml.RX(params[11], wires=4)
        qml.RZ(params[12], wires=2)
        qml.RZ(params[13], wires=4)
        qml.CRZ(params[14], wires=[4, 2])
        qml.CRZ(params[15], wires=[2, 4])
        qml.RX(params[16], wires=2)
        qml.RX(params[17], wires=4)
        qml.RZ(params[18], wires=2)
        qml.RZ(params[19], wires=4)

        # Layer 2 - Pooling
        qml.CRZ(params[32], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[33], wires=[2, 0])
        qml.CRZ(params[32], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[33], wires=[6, 4])

        # Layer 3 - Convolution
        qml.RX(params[20], wires=4)
        qml.RX(params[21], wires=0)
        qml.RZ(params[22], wires=4)
        qml.RZ(params[23], wires=0)
        qml.CRZ(params[24], wires=[0, 4])
        qml.CRZ(params[25], wires=[4, 0])
        qml.RX(params[26], wires=4)
        qml.RX(params[27], wires=0)
        qml.RZ(params[28], wires=4)
        qml.RZ(params[29], wires=0)

        # Layer 3 - Pooling
        qml.CRZ(params[34], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[35], wires=[4, 0])

    # Convolutional Layer #8
    elif U == "U_6":
        # Layer 1 - Convolution
        qml.RX(params[0], wires=7)
        qml.RX(params[1], wires=0)
        qml.RZ(params[2], wires=7)
        qml.RZ(params[3], wires=0)
        qml.CRX(params[4], wires=[0, 7])
        qml.CRX(params[5], wires=[7, 0])
        qml.RX(params[6], wires=7)
        qml.RX(params[7], wires=0)
        qml.RZ(params[8], wires=7)
        qml.RZ(params[9], wires=0)
        for i in range(0, 8, 2):
            qml.RX(params[0], wires=i)
            qml.RX(params[1], wires=i+1)
            qml.RZ(params[2], wires=i)
            qml.RZ(params[3], wires=i+1)
            qml.CRX(params[4], wires=[i+1, i])
            qml.CRX(params[5], wires=[i, i+1])
            qml.RX(params[6], wires=i)
            qml.RX(params[7], wires=i+1)
            qml.RZ(params[8], wires=i)
            qml.RZ(params[9], wires=i+1)
        for i in range(1, 7, 2):
            qml.RX(params[0], wires=i)
            qml.RX(params[1], wires=i+1)
            qml.RZ(params[2], wires=i)
            qml.RZ(params[3], wires=i+1)
            qml.CRX(params[4], wires=[i+1, i])
            qml.CRX(params[5], wires=[i, i+1])
            qml.RX(params[6], wires=i)
            qml.RX(params[7], wires=i+1)
            qml.RZ(params[8], wires=i)
            qml.RZ(params[9], wires=i+1)

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[30], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[31], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.RX(params[10], wires=6)
        qml.RX(params[11], wires=0)
        qml.RZ(params[12], wires=6)
        qml.RZ(params[13], wires=0)
        qml.CRX(params[14], wires=[0, 6])
        qml.CRX(params[15], wires=[6, 0])
        qml.RX(params[16], wires=6)
        qml.RX(params[17], wires=0)
        qml.RZ(params[18], wires=6)
        qml.RZ(params[19], wires=0)
        qml.RX(params[10], wires=0)
        qml.RX(params[11], wires=2)
        qml.RZ(params[12], wires=0)
        qml.RZ(params[13], wires=2)
        qml.CRX(params[14], wires=[2, 0])
        qml.CRX(params[15], wires=[0, 2])
        qml.RX(params[16], wires=0)
        qml.RX(params[17], wires=2)
        qml.RZ(params[18], wires=0)
        qml.RZ(params[19], wires=2)
        qml.RX(params[10], wires=4)
        qml.RX(params[11], wires=6)
        qml.RZ(params[12], wires=4)
        qml.RZ(params[13], wires=6)
        qml.CRX(params[14], wires=[6, 4])
        qml.CRX(params[15], wires=[4, 6])
        qml.RX(params[16], wires=4)
        qml.RX(params[17], wires=6)
        qml.RZ(params[18], wires=4)
        qml.RZ(params[19], wires=6)
        qml.RX(params[10], wires=2)
        qml.RX(params[11], wires=4)
        qml.RZ(params[12], wires=2)
        qml.RZ(params[13], wires=4)
        qml.CRX(params[14], wires=[4, 2])
        qml.CRX(params[15], wires=[2, 4])
        qml.RX(params[16], wires=2)
        qml.RX(params[17], wires=4)
        qml.RZ(params[18], wires=2)
        qml.RZ(params[19], wires=4)

        # Layer 2 - Pooling
        qml.CRZ(params[32], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[33], wires=[2, 0])
        qml.CRZ(params[32], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[33], wires=[6, 4])

        # Layer 3 - Convolution
        qml.RX(params[20], wires=4)
        qml.RX(params[21], wires=0)
        qml.RZ(params[22], wires=4)
        qml.RZ(params[23], wires=0)
        qml.CRX(params[24], wires=[0, 4])
        qml.CRX(params[25], wires=[4, 0])
        qml.RX(params[26], wires=4)
        qml.RX(params[27], wires=0)
        qml.RZ(params[28], wires=4)
        qml.RZ(params[29], wires=0)

        # Layer 3 - Pooling
        qml.CRZ(params[34], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[35], wires=[4, 0])

    # Convolutional Layer #9a
    elif U == "U_SU4":
        # Layer 1 - Convolution
        qml.U3(params[0], params[1], params[2], wires=7)
        qml.U3(params[3], params[4], params[5], wires=0)
        qml.CNOT(wires=[7, 0])
        qml.RY(params[6], wires=7)
        qml.RZ(params[7], wires=0)
        qml.CNOT(wires=[0, 7])
        qml.RY(params[8], wires=7)
        qml.CNOT(wires=[7, 0])
        qml.U3(params[9], params[10], params[11], wires=7)
        qml.U3(params[12], params[13], params[14], wires=0)
        for i in range(0, 8, 2):
            qml.U3(params[0], params[1], params[2], wires=i)
            qml.U3(params[3], params[4], params[5], wires=i+1)
            qml.CNOT(wires=[i, i+1])
            qml.RY(params[6], wires=i)
            qml.RZ(params[7], wires=i+1)
            qml.CNOT(wires=[i+1, i])
            qml.RY(params[8], wires=i)
            qml.CNOT(wires=[i, i+1])
            qml.U3(params[9], params[10], params[11], wires=i)
            qml.U3(params[12], params[13], params[14], wires=i+1)
        for i in range(1, 7, 2):
            qml.U3(params[0], params[1], params[2], wires=i)
            qml.U3(params[3], params[4], params[5], wires=i+1)
            qml.CNOT(wires=[i, i+1])
            qml.RY(params[6], wires=i)
            qml.RZ(params[7], wires=i+1)
            qml.CNOT(wires=[i+1, i])
            qml.RY(params[8], wires=i)
            qml.CNOT(wires=[i, i+1])
            qml.U3(params[9], params[10], params[11], wires=i)
            qml.U3(params[12], params[13], params[14], wires=i+1)

        # Layer 1 - Pooling
        for i in range(0, 8, 2):
            qml.CRZ(params[45], wires=[i+1, i])
            qml.PauliX(wires=i+1)
            qml.CRX(params[46], wires=[i+1, i])

        # Layer 2 - Convolution
        qml.U3(params[15], params[16], params[17], wires=6)
        qml.U3(params[18], params[19], params[20], wires=0)
        qml.CNOT(wires=[6, 0])
        qml.RY(params[21], wires=6)
        qml.RZ(params[22], wires=0)
        qml.CNOT(wires=[0, 6])
        qml.RY(params[23], wires=6)
        qml.CNOT(wires=[6, 0])
        qml.U3(params[24], params[25], params[26], wires=6)
        qml.U3(params[27], params[28], params[29], wires=0)
        qml.U3(params[15], params[16], params[17], wires=0)
        qml.U3(params[18], params[19], params[20], wires=2)
        qml.CNOT(wires=[0, 2])
        qml.RY(params[21], wires=0)
        qml.RZ(params[22], wires=2)
        qml.CNOT(wires=[2, 0])
        qml.RY(params[23], wires=0)
        qml.CNOT(wires=[0, 2])
        qml.U3(params[24], params[25], params[26], wires=0)
        qml.U3(params[27], params[28], params[29], wires=2)
        qml.U3(params[15], params[16], params[17], wires=4)
        qml.U3(params[18], params[19], params[20], wires=6)
        qml.CNOT(wires=[4, 6])
        qml.RY(params[21], wires=4)
        qml.RZ(params[22], wires=6)
        qml.CNOT(wires=[6, 4])
        qml.RY(params[23], wires=4)
        qml.CNOT(wires=[4, 6])
        qml.U3(params[24], params[25], params[26], wires=4)
        qml.U3(params[27], params[28], params[29], wires=6)
        qml.U3(params[15], params[16], params[17], wires=2)
        qml.U3(params[18], params[19], params[20], wires=4)
        qml.CNOT(wires=[2, 4])
        qml.RY(params[21], wires=2)
        qml.RZ(params[22], wires=4)
        qml.CNOT(wires=[4, 2])
        qml.RY(params[23], wires=2)
        qml.CNOT(wires=[2, 4])
        qml.U3(params[24], params[25], params[26], wires=2)
        qml.U3(params[27], params[28], params[29], wires=4)

        # Layer 2 - Pooling
        qml.CRZ(params[47], wires=[2, 0])
        qml.PauliX(wires=2)
        qml.CRX(params[48], wires=[2, 0])
        qml.CRZ(params[47], wires=[6, 4])
        qml.PauliX(wires=6)
        qml.CRX(params[48], wires=[6, 4])

        # Layer 3 - Convolution
        qml.U3(params[30], params[31], params[32], wires=4)
        qml.U3(params[33], params[34], params[35], wires=0)
        qml.CNOT(wires=[4, 0])
        qml.RY(params[36], wires=4)
        qml.RZ(params[37], wires=0)
        qml.CNOT(wires=[0, 4])
        qml.RY(params[38], wires=4)
        qml.CNOT(wires=[4, 0])
        qml.U3(params[39], params[40], params[41], wires=4)
        qml.U3(params[42], params[43], params[44], wires=0)

        # Layer 3 - Pooling
        qml.CRZ(params[49], wires=[4, 0])
        qml.PauliX(wires=4)
        qml.CRX(params[50], wires=[4, 0])

    # Convolutional Layer #9b
    elif U == "U_SU4_no_pooling":
        # Layer 1 - Convolution
        qml.U3(params[0], params[1], params[2], wires=7)
        qml.U3(params[3], params[4], params[5], wires=0)
        qml.CNOT(wires=[7, 0])
        qml.RY(params[6], wires=7)
        qml.RZ(params[7], wires=0)
        qml.CNOT(wires=[0, 7])
        qml.RY(params[8], wires=7)
        qml.CNOT(wires=[7, 0])
        qml.U3(params[9], params[10], params[11], wires=7)
        qml.U3(params[12], params[13], params[14], wires=0)
        for i in range(0, 8, 2):
            qml.U3(params[0], params[1], params[2], wires=i)
            qml.U3(params[3], params[4], params[5], wires=i+1)
            qml.CNOT(wires=[i, i+1])
            qml.RY(params[6], wires=i)
            qml.RZ(params[7], wires=i+1)
            qml.CNOT(wires=[i+1, i])
            qml.RY(params[8], wires=i)
            qml.CNOT(wires=[i, i+1])
            qml.U3(params[9], params[10], params[11], wires=i)
            qml.U3(params[12], params[13], params[14], wires=i+1)
        for i in range(1, 7, 2):
            qml.U3(params[0], params[1], params[2], wires=i)
            qml.U3(params[3], params[4], params[5], wires=i+1)
            qml.CNOT(wires=[i, i+1])
            qml.RY(params[6], wires=i)
            qml.RZ(params[7], wires=i+1)
            qml.CNOT(wires=[i+1, i])
            qml.RY(params[8], wires=i)
            qml.CNOT(wires=[i, i+1])
            qml.U3(params[9], params[10], params[11], wires=i)
            qml.U3(params[12], params[13], params[14], wires=i+1)

        # Layer 2 - Convolution
        qml.U3(params[15], params[16], params[17], wires=6)
        qml.U3(params[18], params[19], params[20], wires=0)
        qml.CNOT(wires=[6, 0])
        qml.RY(params[21], wires=6)
        qml.RZ(params[22], wires=0)
        qml.CNOT(wires=[0, 6])
        qml.RY(params[23], wires=6)
        qml.CNOT(wires=[6, 0])
        qml.U3(params[24], params[25], params[26], wires=6)
        qml.U3(params[27], params[28], params[29], wires=0)
        qml.U3(params[15], params[16], params[17], wires=0)
        qml.U3(params[18], params[19], params[20], wires=2)
        qml.CNOT(wires=[0, 2])
        qml.RY(params[21], wires=0)
        qml.RZ(params[22], wires=2)
        qml.CNOT(wires=[2, 0])
        qml.RY(params[23], wires=0)
        qml.CNOT(wires=[0, 2])
        qml.U3(params[24], params[25], params[26], wires=0)
        qml.U3(params[27], params[28], params[29], wires=2)
        qml.U3(params[15], params[16], params[17], wires=4)
        qml.U3(params[18], params[19], params[20], wires=6)
        qml.CNOT(wires=[4, 6])
        qml.RY(params[21], wires=4)
        qml.RZ(params[22], wires=6)
        qml.CNOT(wires=[6, 4])
        qml.RY(params[23], wires=4)
        qml.CNOT(wires=[4, 6])
        qml.U3(params[24], params[25], params[26], wires=4)
        qml.U3(params[27], params[28], params[29], wires=6)
        qml.U3(params[15], params[16], params[17], wires=2)
        qml.U3(params[18], params[19], params[20], wires=4)
        qml.CNOT(wires=[2, 4])
        qml.RY(params[21], wires=2)
        qml.RZ(params[22], wires=4)
        qml.CNOT(wires=[4, 2])
        qml.RY(params[23], wires=2)
        qml.CNOT(wires=[2, 4])
        qml.U3(params[24], params[25], params[26], wires=2)
        qml.U3(params[27], params[28], params[29], wires=4)

        # Layer 3 - Convolution
        qml.U3(params[30], params[31], params[32], wires=4)
        qml.U3(params[33], params[34], params[35], wires=0)
        qml.CNOT(wires=[4, 0])
        qml.RY(params[36], wires=4)
        qml.RZ(params[37], wires=0)
        qml.CNOT(wires=[0, 4])
        qml.RY(params[38], wires=4)
        qml.CNOT(wires=[4, 0])
        qml.U3(params[39], params[40], params[41], wires=4)
        qml.U3(params[42], params[43], params[44], wires=0)

    # Measurement - return expected X, Y, Z (considering only MSE-type losses)
    result = [qml.expval(qml.PauliX(0)), qml.expval(
        qml.PauliY(0)), qml.expval(qml.PauliZ(0))]
    return result

# %%
# QCNN-Qnode circuit setting (hyper parameter of the function)
# ["Amplitude", "Angle", "Angle-compact", Amplitude-Hybrid4-1, 2, 3, 4, Angular-Hybrid4-1, 2, 3, 4]
Embedding = 'Amplitude'
# ['U_TTN', 'U_9', 'U_15', 'U_13', 'U_14', 'U_SO4', 'U_5', 'U_6', 'U_SU4', 'U_SU4_no_pooling']
U = "U_SU4"
# U_params = [2]    #[2, 2, 4, 6, 6, 6, 10, 10, 15, 15]

# %%
import tensorflow as tf

device_chosen = dev_list[0]

QCNN_Qnode = qml.QNode(QCNN_circuit_node, device=device_chosen, interface="tf")
weight_shapes = {"params": 51}  # [12, 12, 18, 24, 24, 24, 36, 36, 51, 45]
qlayer = qml.qnn.KerasLayer(
    QCNN_Qnode, weight_shapes, output_dim=3, name="qlayer_QCNN")

# %%
# Choose activation function
activation_func = 'relu'  # sigmoid, relu, softmax, tanh,
clayer_1 = tf.keras.layers.Dense(
    3, activation=activation_func, name="clayer"+str(activation_func)+"1")
clayer_2 = tf.keras.layers.Dense(
    3, activation=activation_func, name="clayer"+str(activation_func)+"2")
clayer_3 = tf.keras.layers.Dense(
    3, activation=activation_func, name="clayer"+str(activation_func)+"3")
clayer_4 = tf.keras.layers.Dense(
    3, activation=activation_func, name="clayer"+str(activation_func)+"4")
clayer_5 = tf.keras.layers.Dense(
    3, activation=activation_func, name="clayer"+str(activation_func)+"5")
clayer_final = tf.keras.layers.Dense(
    2, activation="softmax", name="clayer_softmax")

# %%
# Choose the QCNN + NN model
model_QCNN_Qnode0 = tf.keras.models.Sequential(
    [qlayer, clayer_final], name="QCNN - Qnode model0")
model_QCNN_Qnode1 = tf.keras.models.Sequential(
    [qlayer, clayer_1, clayer_final], name="QCNN - Qnode model1")
model_QCNN_Qnode2 = tf.keras.models.Sequential(
    [qlayer, clayer_1, clayer_2, clayer_3, clayer_final], name="QCNN - Qnode model2")
model_QCNN_Qnode3 = tf.keras.models.Sequential(
    [qlayer, clayer_1, clayer_2, clayer_3, clayer_4, clayer_5, clayer_final], name="QCNN - Qnode model3")

# %%
opt = tf.keras.optimizers.SGD(learning_rate=0.1, nesterov=True)

model_QCNN_chosen = model_QCNN_Qnode2
# loss: "binary_crossentropy"
model_QCNN_chosen.compile(opt, loss="mse", metrics=["accuracy"])

# %%
class SaveBatchLoss(tf.keras.callbacks.Callback):
    def on_train_batch_end(self, batch, logs=None):
        batch_end_loss.append(logs['loss'])
        batch_end_accuracy.append(logs['accuracy'])

# %% [markdown]
# ### Circuit Optimization / Results

# %%
num_epoch = 2
minibatch_size = 25
num_train = len(X_train)  # len(X_train)
num_test = len(X_test)  # len(X_test)

batch_end_loss = list()
batch_end_accuracy = list()
fitting = model_QCNN_chosen.fit(x=X_train[0:num_train],
                                y=Y_train_onehot[0:num_train],
                                batch_size=minibatch_size,
                                #steps_per_epoch = num_minibatch_per_epoch,
                                epochs=num_epoch,
                                callbacks=SaveBatchLoss()
                                )
# Out:
# Epoch 1/2
# 507/507 [==============================] - 19069s 38s/step - loss: 0.0289 - accuracy: 0.9735
# Epoch 2/2
# 507/507 [==============================] - 19632s 39s/step - loss: 0.0112 - accuracy: 0.9871

# %%
model_QCNN_chosen.summary()
# Out:
# Model: "QCNN - Qnode model2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  qlayer_QCNN (KerasLayer)    (None, 3)                 51
#
#  clayerrelu1 (Dense)         (None, 3)                 12
#
#  clayerrelu2 (Dense)         (None, 3)                 12
#
#  clayerrelu3 (Dense)         (None, 3)                 12
#
#  clayer_softmax (Dense)      (None, 2)                 8
#
# =================================================================
# Total params: 95
# Trainable params: 95
# Non-trainable params: 0
# _________________________________________________________________

# %%
fitting.history
# Out:
# {'loss': [0.028898077223766392, 0.011219610007408677],
#  'accuracy': [0.9735491512041058, 0.9870509277536518]}

# %%
fitting.history['loss']
# Out:
# [0.028898077223766392, 0.011219610007408677]

# %%
batch_end_loss
# Out:
# [0.2546019301388157,
#  0.23920486119623952,
#  0.23583795828086707,
#  0.23833696326354206,
#  0.232979775355149,
#  0.2242884250975381,
#  0.2214409428452078,
#  0.21644830534912166,
#  0.21166155166165507,
#  0.2055358455456624,
#  0.20122366090653449,
#  0.1988519615607022,
#  0.19569983125668544,
#  0.19247857122092146,
#  0.19162362944120825,
#  0.18765922135088534,
#  0.18597479151286642,
#  0.18512711032479956,
#  0.1824189809297699,
#  0.17859804708269214,
#  0.17658352709143646,
#  0.1750602447556612,
#  0.17242841179631582,
#  0.1700104828319751,
#  0.16895944646967798,
#  0.16761441259564172,
#  0.16636244345337522,
#  0.16382006561429335,
#  0.1616357801117032,
#  0.1597037790403536,
#  0.15754667758102514,
#  0.1559982356073723,
#  0.15424081646941523,
#  0.15230008994204783,
#  0.15047303499123935,
#  0.14909576121793058,
#  0.14744650417355215,
#  0.1463521253211533,
#  0.14483902316921493,
#  0.1435432011766397,
#  0.1419015837635113,
#  0.1402361834934846,
#  0.14024698239807976,
#  0.13852331678233068,
#  0.13683749147718155,
#  0.13530193565487325,
#  0.13337627754362197,
#  0.13189413700146,
#  0.13097754836095968,
#  0.12995200574407892,
#  0.1283463117326103,
#  0.12730784287198796,
#  0.1257372079974318,
#  0.12444232934657276,
#  0.12309382348419147,
#  0.12197413702172394,
#  0.12069725670796742,
#  0.11946710966533597,
#  0.11848337522171039,
#  0.11720797465211985,
#  0.11600010801520373,
#  0.11481412965019881,
#  0.11385096315544034,
#  0.11281088262300257,
#  0.11173970198025955,
#  0.11059534806102188,
#  0.10991264055575634,
#  0.10889878816047698,
#  0.10813164518610661,
#  0.1075777563109678,
#  0.10667241833152155,
#  0.10561935320369709,
#  0.10469969130490199,
#  0.1040666577006598,
#  0.10347699415495942,
#  0.1027264199956438,
#  0.10189931311986906,
#  0.10121725380599858,
#  0.1004204372823463,
#  0.09983697934450103,
#  0.09895642269202766,
#  0.09804670817151083,
#  0.09724201484436262,
#  0.09659035283552768,
#  0.09596626273769379,
#  0.09517889114345983,
#  0.09436629221738568,
#  0.0937086635356738,
#  0.09293575841356451,
#  0.09211148358370805,
#  0.09126603503392826,
#  0.0904756456381989,
#  0.08971305601723853,
#  0.0889500028233479,
#  0.08883688806485615,
#  0.08811368318189626,
#  0.08744621155455026,
#  0.08681340728826416,
#  0.08611345800857415,
#  0.08539418877604858,
#  0.08471765858304169,
#  0.08414276981601401,
#  0.08383400613890314,
#  0.08339339912976095,
#  0.08286151116749783,
#  0.08240099314228648,
#  0.0817964796064775,
#  0.08124118238973081,
#  0.08093791518305787,
#  0.08036340423612015,
#  0.07992922609736255,
#  0.07935019899851531,
#  0.07892587449648471,
#  0.07859072807244646,
#  0.07802303206113463,
#  0.07748668017545081,
#  0.07702928463089509,
#  0.07648158937270098,
#  0.07606447730659077,
#  0.0757061141122266,
#  0.07524760170157017,
#  0.07508361575649172,
#  0.0747666488274757,
#  0.07435369780949656,
#  0.07389879059782341,
#  0.07349092598652172,
#  0.072987355060191,
#  0.07265988994441464,
#  0.0721626399655736,
#  0.07167875744801389,
#  0.07120501964479478,
#  0.07102344127651924,
#  0.07062596881063612,
#  0.07019991809969323,
#  0.07018528321694462,
#  0.06982286326991101,
#  0.06957721346622732,
#  0.06914243703005767,
#  0.06875003489689084,
#  0.06835155542774694,
#  0.06820669243255144,
#  0.06780215273784482,
#  0.06744741466744916,
#  0.06709367019850225,
#  0.06694280629000841,
#  0.06657902380389623,
#  0.06618852249713239,
#  0.06592194498515347,
#  0.0655189477462083,
#  0.06519960628455963,
#  0.06483628258008513,
#  0.0646423066053168,
#  0.0645296515580054,
#  0.06432788777396917,
#  0.06396261287783474,
#  0.0636168989954323,
#  0.06356426922681584,
#  0.0632371929727219,
#  0.06292390222843357,
#  0.06261466300273036,
#  0.06226166897252704,
#  0.06204959345407753,
#  0.06171063155095745,
#  0.06138776239081564,
#  0.06106326431437174,
#  0.060743579667674415,
#  0.06041309415101803,
#  0.06009215945102844,
#  0.05977906923619508,
#  0.059473004393015824,
#  0.05916925770913263,
#  0.05887104467293214,
#  0.05878291658864266,
#  0.05859616220549913,
#  0.058297588114156404,
#  0.058087635792601205,
#  0.05790796300293495,
#  0.05761936895238245,
#  0.057416727153616676,
#  0.05743645978641599,
#  0.057660278410406864,
#  0.0573848112064333,
#  0.057100912785124726,
#  0.05708537754188024,
#  0.056931255364457374,
#  0.0567307775172931,
#  0.05649795773603048,
#  0.05622990577115828,
#  0.055964833516107045,
#  0.05576629664084955,
#  0.05550335251045371,
#  0.05524950948823573,
#  0.055209685369781235,
#  0.054997011435455864,
#  0.05479993547256178,
#  0.05467849141277479,
#  0.05446694337034109,
#  0.05423459839166055,
#  0.05402203066151677,
#  0.05382810732032089,
#  0.05364337423380783,
#  0.053413242486185876,
#  0.05323059280334942,
#  0.0531028616058236,
#  0.05303585672539234,
#  0.05294957782316802,
#  0.05276182663796005,
#  0.0526633456366393,
#  0.052552108437168246,
#  0.0523578976638065,
#  0.052174490944650376,
#  0.05199398280029021,
#  0.05178716147301174,
#  0.05162444608151847,
#  0.05141617268498129,
#  0.0512117719866192,
#  0.05103376660957943,
#  0.050821395808964026,
#  0.050618259770867834,
#  0.050415464415363584,
#  0.0503487689011792,
#  0.05017284315920558,
#  0.049977464145749835,
#  0.049774968410837166,
#  0.049582530541617445,
#  0.04958958995980293,
#  0.049419207780684905,
#  0.04921974029255664,
#  0.04912137688138214,
#  0.04906615789704931,
#  0.049116211680416653,
#  0.049070639215746316,
#  0.04887907447903818,
#  0.04883516257660054,
#  0.048659584391959734,
#  0.0484717222671076,
#  0.048309221004693044,
#  0.04814119964352654,
#  0.047973152489444316,
#  0.04778537286195219,
#  0.047620464511239385,
#  0.047579682800028666,
#  0.04741510438015468,
#  0.04724491465509816,
#  0.04707040614709499,
#  0.046913916382642216,
#  0.04673735079923636,
#  0.046696532344517885,
#  0.04664316662056554,
#  0.046484438762109885,
#  0.04632037808753124,
#  0.0461851146108299,
#  0.046018131173274614,
#  0.04587414393887538,
#  0.045718315222641526,
#  0.04557517729146339,
#  0.04541542511882564,
#  0.0452768119565784,
#  0.045250231649367006,
#  0.04524340954072685,
#  0.045137060126796684,
#  0.044975680059409044,
#  0.04483466815656738,
#  0.04472902880748966,
#  0.04457561003368549,
#  0.04450147287717835,
#  0.04438416861825936,
#  0.04427647217901066,
#  0.04412653928506457,
#  0.04398402589029259,
#  0.043863763961255194,
#  0.04383986221371981,
#  0.04369453745087747,
#  0.043552452008634356,
#  0.043458181658921985,
#  0.043313195482769185,
#  0.043167675767667474,
#  0.043023017621970076,
#  0.043033471782428424,
#  0.042910102605192846,
#  0.04277117053846842,
#  0.04263348316892802,
#  0.04255073268955707,
#  0.04241719619218929,
#  0.04228244582456585,
#  0.04220418365966596,
#  0.04216312519921504,
#  0.042033551121755754,
#  0.04205574792596344,
#  0.04192091915902632,
#  0.04178906380127962,
#  0.04187883916955498,
#  0.041756662845216,
#  0.041631596741185516,
#  0.04150295004936674,
#  0.04138498935922244,
#  0.041259721966353455,
#  0.04114760808523877,
#  0.04103081077821197,
#  0.04090828488188163,
#  0.04078280453121038,
#  0.040683674827963916,
#  0.04055795824349824,
#  0.04043775984984867,
#  0.040350293042413186,
#  0.040229919935847534,
#  0.04016327232581811,
#  0.04004374981205358,
#  0.04016259047431639,
#  0.04004937788452456,
#  0.039930415490727386,
#  0.039811228527460246,
#  0.03969130900996324,
#  0.03957548140706072,
#  0.039505789445145136,
#  0.039481054896846966,
#  0.03945306359547799,
#  0.039355221859119306,
#  0.039254914208590064,
#  0.03924557763700112,
#  0.03913577786664934,
#  0.039022106039715475,
#  0.039035964032557706,
#  0.03892327643457058,
#  0.03881127918567221,
#  0.038703515514386444,
#  0.03859655431125984,
#  0.038568313269610695,
#  0.03846373478961194,
#  0.038356898361180225,
#  0.038249161347672374,
#  0.03814720818999487,
#  0.038055590068399224,
#  0.037997347846591194,
#  0.03791253511010045,
#  0.03787958026053053,
#  0.03778257470973069,
#  0.03767702925631417,
#  0.037610038505879025,
#  0.03750799879616368,
#  0.03741663499592689,
#  0.037323517185055985,
#  0.03722181554193247,
#  0.03712419333768724,
#  0.03711594913828618,
#  0.037032893087760116,
#  0.03694288856463424,
#  0.03685908660127256,
#  0.03676556276370701,
#  0.03682405409857923,
#  0.03677748150896394,
#  0.036680417815385204,
#  0.036594022010757205,
#  0.03650137090984542,
#  0.036411116286343664,
#  0.03631529959215196,
#  0.03622941204933242,
#  0.03615380187977076,
#  0.036069835479050495,
#  0.03597882251584229,
#  0.03592421684546518,
#  0.03583731552179975,
#  0.03574430949932481,
#  0.035694329883068775,
#  0.0356143508806101,
#  0.03552950041364194,
#  0.035440490305310254,
#  0.035350936229997125,
#  0.0353340287201373,
#  0.03526661127180259,
#  0.03527788644024213,
#  0.03519860406034626,
#  0.03510822761019713,
#  0.035067294730713204,
#  0.03499179202808639,
#  0.03491000766906996,
#  0.03484900692453351,
#  0.034867741485591214,
#  0.0347913770528461,
#  0.03470500973504361,
#  0.034665122806224975,
#  0.03458138536100254,
#  0.03453577589252391,
#  0.03445066211712709,
#  0.034376012884870445,
#  0.03430130846605922,
#  0.03421979671409604,
#  0.03413711194206713,
#  0.03406793113563004,
#  0.03399161817841128,
#  0.03391059054835026,
#  0.033879600359755846,
#  0.033797670727346234,
#  0.03379907154846498,
#  0.03371792173773604,
#  0.03372699027439306,
#  0.0336666501329575,
#  0.03361111951503977,
#  0.03353285114239702,
#  0.03350498968320185,
#  0.03352136176749379,
#  0.03345039450288463,
#  0.03337407349995627,
#  0.033302854110189684,
#  0.033257472957692005,
#  0.03320120161045098,
#  0.03312450830976772,
#  0.033055599794244675,
#  0.032977790799379604,
#  0.03290385883450115,
#  0.03282734880717402,
#  0.03275269004680776,
#  0.0326786946099279,
#  0.03260425556310062,
#  0.03254073398839693,
#  0.03248681611212475,
#  0.03242112341219632,
#  0.03235218410905828,
#  0.03227832573140223,
#  0.032216094132307915,
#  0.0321839705656367,
#  0.032114604085768425,
#  0.03208209572826587,
#  0.03201100424158958,
#  0.032066705086370925,
#  0.03199486011416374,
#  0.031928814313278056,
#  0.03185818881738522,
#  0.03187343681812431,
#  0.03183821962185316,
#  0.03187246878016843,
#  0.03181361429376299,
#  0.0317846726270328,
#  0.03182457734460958,
#  0.03176632285027163,
#  0.03170443759833362,
#  0.03164167639566669,
#  0.031573606348665274,
#  0.03150741203280817,
#  0.03144808600945448,
#  0.031381912751030146,
#  0.03131976385051557,
#  0.03127197161939702,
#  0.03120446103242761,
#  0.031147023288709632,
#  0.031082542359775492,
#  0.03101564233699217,
#  0.030950175900032274,
#  0.03088583047152385,
#  0.030820723012309578,
#  0.030812681291553973,
#  0.030835350659728433,
#  0.030772158629761667,
#  0.03070880457249571,
#  0.030646614852517674,
#  0.030584640734619615,
#  0.030605170250685532,
#  0.030547760431849705,
#  0.03048984544551921,
#  0.030427926747158204,
#  0.030368229342260498,
#  0.030308671331327725,
#  0.030256895895975952,
#  0.030199542256080507,
#  0.03013928169882893,
#  0.030161514190211063,
#  0.03009992155731667,
#  0.03003833047188934,
#  0.029986764907334193,
#  0.02995185043850762,
#  0.029972811946488608,
#  0.0299127994677941,
#  0.029964478565591722,
#  0.029904460002035324,
#  0.029853451798413467,
#  0.029795179226177172,
#  0.029734946772309367,
#  0.02967637272010772,
#  0.02963314543749237,
#  0.029611665501374878,
#  0.029568184945693538,
#  0.02951450359123527,
#  0.02945663875128036,
#  0.029403736725927748,
#  0.029443625544565262,
#  0.029428244811983195,
#  0.02937027978736744,
#  0.029399204769660618,
#  0.029341560085021073,
#  0.029335169327498172,
#  0.029278312876847904,
#  0.02922188850844029,
#  0.0291676667376842,
#  0.029110891451623284,
#  0.029178987550309236,
#  0.029133103089419077,
#  0.02915277555305573,
#  0.029100466328923266,
#  0.029046146991170068,
#  0.02899430233748931,
#  0.02894808501086769,
#  0.02890019059852284,
#  0.028922454014679574,
#  0.029016366262810567,
#  0.02897637621628682,
#  0.02892232167619744,
#  0.028898077223766392,
#  0.03219126240399607,
#  0.02467649367409611,
#  0.020002524054262616,
#  0.015351518242094913,
#  0.012459258887649344,
#  0.011884052975348655,
#  0.013321984937252332,
#  0.01507981621250904,
#  0.015576971256969467,
#  0.014138586428711656,
#  0.013948770852539797,
#  0.012998833357646728,
#  0.01244781064278309,
#  0.011690238819107345,
#  0.01109122452824835,
#  0.010811575408984187,
#  0.01242138292555075,
#  0.012093911947353675,
#  0.011506947112588692,
#  0.010999811814442931,
#  0.012247709432277216,
#  0.013642965356243368,
#  0.014426475345833197,
#  0.013910270928744988,
#  0.01345555594354123,
#  0.01354579213546879,
#  0.013220774018906383,
#  0.012849240033107114,
#  0.014025549325347162,
#  0.014724698694164989,
#  0.014414340904054026,
#  0.014766891898428534,
#  0.01633350634599596,
#  0.015915939666153067,
#  0.015518503322797642,
#  0.015128057418557196,
#  0.014829350429874544,
#  0.01447829816089373,
#  0.014593283561923059,
#  0.014329532321766859,
#  0.014020254775311793,
#  0.013702495904291182,
#  0.01392793237245922,
#  0.013666283195907254,
#  0.01338669459589456,
#  0.01314324098289585,
#  0.01289537316756738,
#  0.012651414061851367,
#  0.012752906122178267,
#  0.012635535681432991,
#  0.012567859600138188,
#  0.012346845092298475,
#  0.012133039857093514,
#  0.012259065931269545,
#  0.012062196557752331,
#  0.011992558621396915,
#  0.011855547467839301,
#  0.011758854789911859,
#  0.012098701883310699,
#  0.012281483698947425,
#  0.012316353038179512,
#  0.012647094449567912,
#  0.012591879028037857,
#  0.012452965925592342,
#  0.012519683134325303,
#  0.012344345431253307,
#  0.012184648486430832,
#  0.012181803930191465,
#  0.012594121312543768,
#  0.012502568847817605,
#  0.012347841774864572,
#  0.012189949531328279,
#  0.012144837355418736,
#  0.012468246441799542,
#  0.012875683959795638,
#  0.01272977138574007,
#  0.01288815229242815,
#  0.012770330602821461,
#  0.012628540158739602,
#  0.012640624589053559,
#  0.012492232746009042,
#  0.01298870126360695,
#  0.01285916557048593,
#  0.012935633596493188,
#  0.012794967004255853,
#  0.012916193988290999,
#  0.01309232878876395,
#  0.013037510009626914,
#  0.012992662424120179,
#  0.012901807588005014,
#  0.012817003270243777,
#  0.0127051155346249,
#  0.013280402062742735,
#  0.013426502373759969,
#  0.013315138441371761,
#  0.01318799721996513,
#  0.013649823573586243,
#  0.013522728202872893,
#  0.013394045896524417,
#  0.013418412373971844,
#  0.013307891440952296,
#  0.01320692026777842,
#  0.01311070909728852,
#  0.013488583438207576,
#  0.01339449842774811,
#  0.01329913144184371,
#  0.013184337517607912,
#  0.013076718545049135,
#  0.012974836313651126,
#  0.012870032384683691,
#  0.012809539664885504,
#  0.012740350189560894,
#  0.012633972705420516,
#  0.01254020841420917,
#  0.0125143458929747,
#  0.012760045719187483,
#  0.012662098605353101,
#  0.01257057829974085,
#  0.012472999637225068,
#  0.012623456119167068,
#  0.012545503552798465,
#  0.012451213188231416,
#  0.012534427878344306,
#  0.01244006467103997,
#  0.012406797242099369,
#  0.012314365197930974,
#  0.01222254458866405,
#  0.012134028272644594,
#  0.012048496386519978,
#  0.012051346326763319,
#  0.01213865992312353,
#  0.012062504494709641,
#  0.012342241159000397,
#  0.012298699439867639,
#  0.012642733435806124,
#  0.012583329736896633,
#  0.012539949141976639,
#  0.012458870015706355,
#  0.012535442852484044,
#  0.01245490673668907,
#  0.012380699744176365,
#  0.012402228999210127,
#  0.012322801261713394,
#  0.012280797400378081,
#  0.012212961259077415,
#  0.012135483199531082,
#  0.012072315283214279,
#  0.012095129119663022,
#  0.01203030584693116,
#  0.01197987158944112,
#  0.011967806268945985,
#  0.011901717032420182,
#  0.011831875267913844,
#  0.011772031523602873,
#  0.01173215962797936,
#  0.011669795176102744,
#  0.011666043136752277,
#  0.011613447752715294,
#  0.011545855176457676,
#  0.011497475692426977,
#  0.011665081224974519,
#  0.011597993520959554,
#  0.01153324003718221,
#  0.011497369441496316,
#  0.01165691127776005,
#  0.011595640062051705,
#  0.011543576273218722,
#  0.011482338765575643,
#  0.011422800801226178,
#  0.01135928060746236,
#  0.011303743225872881,
#  0.011308812023686044,
#  0.01127992922279663,
#  0.011235608139993768,
#  0.011175986334152602,
#  0.011173620307733048,
#  0.011246365113940813,
#  0.01135253202691766,
#  0.011308583083622979,
#  0.011515940419771043,
#  0.01145584668513909,
#  0.011789400858847538,
#  0.011941655813481606,
#  0.011882883306820835,
#  0.011846853203560333,
#  0.011805517586237685,
#  0.011883790242785434,
#  0.01182523119491193,
#  0.011765893084943272,
#  0.01170948424114131,
#  0.011686468567956649,
#  0.011647448963547354,
#  0.011607093580218419,
#  0.011555292265949677,
#  0.011597998590148609,
#  0.011543027380801717,
#  0.011488846098837952,
#  0.011640357102643342,
#  0.011606755801520999,
#  0.011552423203232177,
#  0.01168695773631918,
#  0.011687953073790983,
#  0.011632902166165977,
#  0.011596200371503312,
#  0.011805928926809185,
#  0.011752907578357577,
#  0.011707883963538822,
#  0.01165522079991997,
#  0.011604733702591893,
#  0.011580966172088517,
#  0.011532858713372037,
#  0.011530881443378858,
#  0.011482051187273731,
#  0.011432861482853598,
#  0.011383400359844618,
#  0.011334002533835541,
#  0.01128848949253287,
#  0.011240282478811195,
#  0.011394140403814982,
#  0.011346051769379783,
#  0.011304860652628515,
#  0.011478210008805646,
#  0.011467976361244362,
#  0.011419862152421982,
#  0.011429730492986808,
#  0.011382880866369313,
#  0.011338229976335643,
#  0.011456397015005271,
#  0.011409482609725737,
#  0.011371550691591742,
#  0.011388709261139844,
#  0.011517834744336103,
#  0.011477534507461012,
#  0.011433598558326858,
#  0.011402553414303903,
#  0.011523976389563957,
#  0.011479364477886186,
#  0.011495702928070149,
#  0.011662962485474604,
#  0.011660320506607327,
#  0.011616673524341635,
#  0.011573853854882504,
#  0.011529398080778967,
#  0.011588790792461959,
#  0.011561478062200486,
#  0.011683140114479105,
#  0.011638583253707193,
#  0.01159494184824349,
#  0.011551970984911722,
#  0.011508536613179228,
#  0.011466625559514108,
#  0.01142363899550089,
#  0.01146986082773853,
#  0.011556467785251342,
#  0.011526082635198361,
#  0.011494756125124031,
#  0.011452058828365017,
#  0.01157414798309386,
#  0.011553990042253734,
#  0.011527026240825756,
#  0.011489159175899637,
#  0.011449241739689017,
#  0.011408166425768225,
#  0.011369513478037463,
#  0.011330392206989018,
#  0.011290517135713189,
#  0.011279981342445308,
#  0.011318633184264378,
#  0.011304608862231093,
#  0.011408063035928015,
#  0.0114678185746892,
#  0.011436488171342301,
#  0.011399539685470347,
#  0.011499752557751331,
#  0.011460466031950736,
#  0.011563014312183295,
#  0.011661300190158904,
#  0.01162936224381624,
#  0.01159056896867985,
#  0.011551624516418894,
#  0.011512940906172563,
#  0.011474220090959823,
#  0.011476442783031622,
#  0.011467898577383348,
#  0.011432885717278787,
#  0.011466706255243205,
#  0.011429863196805399,
#  0.011423199150235971,
#  0.011392029832490543,
#  0.011484941871403968,
#  0.011448938431250059,
#  0.011437360091670144,
#  0.011403442421395755,
#  0.011370864398066758,
#  0.011341546370020161,
#  0.011304911997077978,
#  0.011276477688335756,
#  0.011311798991796154,
#  0.01128424176126823,
#  0.011249047941891605,
#  0.011221008469567705,
#  0.011187008272499013,
#  0.011174778130809564,
#  0.011146236365273609,
#  0.011112926921382018,
#  0.011085142960648612,
#  0.011082645763676416,
#  0.011161437002412618,
#  0.011151928380314303,
#  0.011117540849275584,
#  0.011086521611745604,
#  0.011056546157887035,
#  0.011158708408257926,
#  0.011159835751783545,
#  0.011195087658663446,
#  0.01116104173756471,
#  0.011135308840820495,
#  0.011103421624205714,
#  0.011077928630712325,
#  0.011093024371563192,
#  0.011141791034943551,
#  0.01110857811455479,
#  0.011094241611733998,
#  0.011061937791998653,
#  0.011029870355115823,
#  0.01099825121740379,
#  0.010967493400500435,
#  0.011093381897374743,
#  0.011085412885934554,
#  0.011074368529858153,
#  0.011044687615315355,
#  0.011127390054966527,
#  0.01109552925437078,
#  0.01107423258020188,
#  0.011091368815163876,
#  0.011274128331393577,
#  0.011242381944477227,
#  0.011250658782206071,
#  0.011221226452637144,
#  0.011190487636363525,
#  0.011159971218427647,
#  0.011143017975254525,
#  0.011127270112684549,
#  0.011169107636452213,
#  0.011254195937495291,
#  0.011228792600721559,
#  0.011197690757830663,
#  0.011193783160776915,
#  0.011166002877505486,
#  0.011135934259312932,
#  0.011124513397936426,
#  0.011095365237935419,
#  0.011149126689571102,
#  0.011119216782576808,
#  0.011091516204353384,
#  0.011181401584792793,
#  0.011159004880612269,
#  0.011129249105070488,
#  0.01109974994350682,
#  0.011214561966396254,
#  0.01122426111943354,
#  0.011194868750187312,
#  0.01116602718857522,
#  0.011175391424773078,
#  0.011215490471133096,
#  0.01118749991492196,
#  0.011158352947768195,
#  0.011269480011757047,
#  0.011295061871499739,
#  0.01126620673511385,
#  0.011238330753243908,
#  0.011390887249363994,
#  0.011362140807181445,
#  0.011416128288245371,
#  0.01146002537980068,
#  0.011437994279722558,
#  0.01144181331365721,
#  0.011489040579462574,
#  0.011467915300821285,
#  0.011473884104643336,
#  0.011490397350264782,
#  0.011474953827408126,
#  0.011527319701848993,
#  0.011500330604226294,
#  0.011473198261883887,
#  0.011546259482806897,
#  0.011533441595116902,
#  0.0115126764095981,
#  0.011484771265255031,
#  0.011461529186379067,
#  0.011433521730849655,
#  0.011499516900397364,
#  0.011572931420423559,
#  0.011553185304004709,
#  0.011625483342062435,
#  0.01159966263058846,
#  0.011590852790681892,
#  0.011564026303977112,
#  0.011535860620783383,
#  0.011545325733226313,
#  0.0115174937389948,
#  0.011489966459066508,
#  0.011462491477096711,
#  0.011441429932704967,
#  0.011415960937613316,
#  0.01141382855903889,
#  0.011391559237285607,
#  0.011456588117152692,
#  0.011433014482507338,
#  0.01144984281832792,
#  0.01142296457659541,
#  0.011397606737238131,
#  0.011388724886551507,
#  0.011362629032791111,
#  0.011338655322041796,
#  0.011406502449875771,
#  0.01138265454305316,
#  0.011356762878680222,
#  0.01133172401774369,
#  0.0113133916058123,
#  0.01128768615616066,
#  0.011269468432722335,
#  0.011244506316172373,
#  0.011221046867149436,
#  0.011201131268398513,
#  0.01125039329451449,
#  0.01122847376946513,
#  0.011230167650697656,
#  0.011205663944063865,
#  0.011181600450210272,
#  0.011162549844908396,
#  0.01119413548762115,
#  0.01116966451822199,
#  0.011234742663731034,
#  0.011214923782313584,
#  0.011190836983392191,
#  0.011233691361525388,
#  0.011210235042822373,
#  0.011188058660208186,
#  0.011169066727600464,
#  0.011231555395413302,
#  0.011207595486685684,
#  0.011275131755996445,
#  0.011293661312584642,
#  0.01127133636164635,
#  0.011279153923993684,
#  0.011254934944965898,
#  0.011234626426857882,
#  0.01124815915218068,
#  0.011287468510979733,
#  0.011264783016362205,
#  0.011240664302072809,
#  0.01121844138606017,
#  0.011195854516811187,
#  0.011172622581677012,
#  0.011226693873409906,
#  0.011274009162376314,
#  0.011253704455124632,
#  0.011293746984645529,
#  0.011272008145589877,
#  0.011253279011429805,
#  0.011315056086769892,
#  0.011296964690282397,
#  0.011278084246308946,
#  0.011255395022515468,
#  0.011243981334724576,
#  0.011221480303406946,
#  0.011246437952066948,
#  0.01124940509080211,
#  0.011226235846992628,
#  0.011214402839612295,
#  0.011200755070369259,
#  0.011183348237320015,
#  0.011168245645483348,
#  0.01114581138998589,
#  0.011202936119715174,
#  0.01127012346656367,
#  0.011249283650568074,
#  0.011226853894863963,
#  0.011204527038798302,
#  0.011273787794188328,
#  0.011252248466806843,
#  0.011238916651688703,
#  0.01121837976503827,
#  0.011207072180479649,
#  0.01118493781142024,
#  0.011162873947882365,
#  0.011142997959150129,
#  0.011205388860900497,
#  0.011185114106991356,
#  0.011244391234446618,
#  0.011223157053874736,
#  0.011201327521364933,
#  ...]

# %%
len(batch_end_loss)
# Out:
# 1014

# %%
batch_end_accuracy
# Out:
# [0.4,
#  0.46,
#  0.4533333333333333,
#  0.43,
#  0.424,
#  0.4533333333333333,
#  0.44571428571428573,
#  0.465,
#  0.4711111111111111,
#  0.488,
#  0.49454545454545457,
#  0.5,
#  0.5384615384615384,
#  0.54,
#  0.5706666666666667,
#  0.5975,
#  0.6211764705882353,
#  0.64,
#  0.6547368421052632,
#  0.67,
#  0.6838095238095238,
#  0.6963636363636364,
#  0.7095652173913043,
#  0.7216666666666667,
#  0.728,
#  0.7369230769230769,
#  0.7437037037037038,
#  0.7528571428571429,
#  0.7613793103448275,
#  0.7693333333333333,
#  0.775483870967742,
#  0.7825,
#  0.7890909090909091,
#  0.7952941176470588,
#  0.8011428571428572,
#  0.8055555555555556,
#  0.8108108108108109,
#  0.8147368421052632,
#  0.8194871794871795,
#  0.824,
#  0.8282926829268292,
#  0.8323809523809523,
#  0.8334883720930233,
#  0.8372727272727273,
#  0.8408888888888889,
#  0.8434782608695652,
#  0.8468085106382979,
#  0.85,
#  0.8522448979591837,
#  0.8552,
#  0.8580392156862745,
#  0.8607692307692307,
#  0.8633962264150944,
#  0.8651851851851852,
#  0.8676363636363637,
#  0.87,
#  0.872280701754386,
#  0.8744827586206897,
#  0.8759322033898305,
#  0.878,
#  0.88,
#  0.8819354838709678,
#  0.8838095238095238,
#  0.885625,
#  0.8867692307692308,
#  0.8884848484848484,
#  0.8895522388059701,
#  0.8911764705882353,
#  0.8927536231884058,
#  0.8937142857142857,
#  0.8952112676056339,
#  0.8966666666666666,
#  0.8980821917808219,
#  0.898918918918919,
#  0.8992,
#  0.9,
#  0.9007792207792208,
#  0.9015384615384615,
#  0.9027848101265823,
#  0.9035,
#  0.9046913580246914,
#  0.9058536585365854,
#  0.9069879518072289,
#  0.9080952380952381,
#  0.9087058823529411,
#  0.9097674418604651,
#  0.9108045977011494,
#  0.9113636363636364,
#  0.9123595505617977,
#  0.9133333333333333,
#  0.9142857142857143,
#  0.9152173913043479,
#  0.9161290322580645,
#  0.9170212765957447,
#  0.9170526315789473,
#  0.9179166666666667,
#  0.9187628865979381,
#  0.9195918367346939,
#  0.9204040404040404,
#  0.9212,
#  0.921980198019802,
#  0.9227450980392157,
#  0.9231067961165048,
#  0.9238461538461539,
#  0.9245714285714286,
#  0.9252830188679245,
#  0.925981308411215,
#  0.9266666666666666,
#  0.9269724770642201,
#  0.9276363636363636,
#  0.9279279279279279,
#  0.9285714285714286,
#  0.9292035398230089,
#  0.9294736842105263,
#  0.9300869565217391,
#  0.9306896551724138,
#  0.9312820512820513,
#  0.931864406779661,
#  0.9321008403361345,
#  0.9323333333333333,
#  0.932892561983471,
#  0.9327868852459016,
#  0.9330081300813008,
#  0.9332258064516129,
#  0.93376,
#  0.933968253968254,
#  0.934488188976378,
#  0.9346875,
#  0.9351937984496124,
#  0.9356923076923077,
#  0.9361832061068702,
#  0.9363636363636364,
#  0.9368421052631579,
#  0.9373134328358209,
#  0.9371851851851852,
#  0.9373529411764706,
#  0.9375182481751825,
#  0.9379710144927537,
#  0.9384172661870503,
#  0.9388571428571428,
#  0.9390070921985816,
#  0.9394366197183098,
#  0.9398601398601398,
#  0.9402777777777778,
#  0.9401379310344827,
#  0.9405479452054795,
#  0.940952380952381,
#  0.9410810810810811,
#  0.9414765100671141,
#  0.9418666666666666,
#  0.942251655629139,
#  0.9423684210526316,
#  0.9424836601307189,
#  0.9425974025974025,
#  0.9429677419354838,
#  0.9433333333333334,
#  0.9434394904458598,
#  0.9437974683544303,
#  0.9441509433962264,
#  0.9445,
#  0.9448447204968944,
#  0.9449382716049383,
#  0.945276073619632,
#  0.9456097560975609,
#  0.945939393939394,
#  0.9462650602409639,
#  0.9465868263473054,
#  0.9469047619047619,
#  0.9472189349112426,
#  0.9475294117647058,
#  0.9478362573099415,
#  0.9481395348837209,
#  0.9479768786127167,
#  0.9480459770114943,
#  0.9483428571428572,
#  0.9486363636363636,
#  0.9487005649717514,
#  0.9489887640449438,
#  0.949050279329609,
#  0.9488888888888889,
#  0.9485082872928177,
#  0.9487912087912088,
#  0.9490710382513661,
#  0.9489130434782609,
#  0.948972972972973,
#  0.9490322580645161,
#  0.9493048128342246,
#  0.9495744680851064,
#  0.9498412698412698,
#  0.9501052631578948,
#  0.9503664921465969,
#  0.950625,
#  0.9506735751295337,
#  0.9509278350515464,
#  0.9511794871794872,
#  0.9512244897959183,
#  0.9514720812182741,
#  0.9517171717171717,
#  0.9519597989949748,
#  0.9522,
#  0.9524378109452736,
#  0.9526732673267326,
#  0.9527093596059113,
#  0.9527450980392157,
#  0.952780487804878,
#  0.9528155339805825,
#  0.9528502415458937,
#  0.9528846153846153,
#  0.9529186602870814,
#  0.9531428571428572,
#  0.9533649289099526,
#  0.9535849056603773,
#  0.9538028169014084,
#  0.9538317757009346,
#  0.954046511627907,
#  0.9542592592592593,
#  0.9544700460829493,
#  0.9546788990825688,
#  0.9548858447488584,
#  0.9550909090909091,
#  0.9551131221719457,
#  0.9553153153153153,
#  0.9555156950672645,
#  0.9557142857142857,
#  0.9559111111111112,
#  0.9557522123893806,
#  0.9559471365638766,
#  0.956140350877193,
#  0.9561572052401747,
#  0.9561739130434782,
#  0.956017316017316,
#  0.9560344827586207,
#  0.9562231759656652,
#  0.9562393162393162,
#  0.9564255319148937,
#  0.9566101694915254,
#  0.9567932489451477,
#  0.9569747899159664,
#  0.9571548117154812,
#  0.9573333333333334,
#  0.9575103734439834,
#  0.9575206611570248,
#  0.9576954732510288,
#  0.9578688524590164,
#  0.9580408163265306,
#  0.9582113821138212,
#  0.9583805668016194,
#  0.9583870967741935,
#  0.9583935742971887,
#  0.95856,
#  0.9587250996015936,
#  0.9588888888888889,
#  0.9590513833992095,
#  0.9592125984251969,
#  0.9593725490196079,
#  0.95953125,
#  0.9596887159533074,
#  0.95984496124031,
#  0.9598455598455599,
#  0.9598461538461538,
#  0.96,
#  0.9601526717557252,
#  0.9603041825095057,
#  0.9604545454545454,
#  0.9606037735849057,
#  0.9606015037593985,
#  0.960749063670412,
#  0.9607462686567164,
#  0.9608921933085501,
#  0.961037037037037,
#  0.9611808118081181,
#  0.9611764705882353,
#  0.9613186813186814,
#  0.9614598540145985,
#  0.9614545454545455,
#  0.9615942028985507,
#  0.9617328519855596,
#  0.9618705035971223,
#  0.9618637992831541,
#  0.962,
#  0.962135231316726,
#  0.9622695035460993,
#  0.96226148409894,
#  0.9623943661971831,
#  0.9625263157894737,
#  0.9625174825174825,
#  0.9625087108013938,
#  0.9626388888888889,
#  0.9626297577854671,
#  0.9627586206896551,
#  0.9628865979381444,
#  0.9627397260273972,
#  0.9628668941979522,
#  0.9629931972789115,
#  0.9631186440677966,
#  0.9632432432432433,
#  0.9633670033670033,
#  0.963489932885906,
#  0.9636120401337792,
#  0.9637333333333333,
#  0.9638538205980066,
#  0.9639735099337748,
#  0.9640924092409241,
#  0.9642105263157895,
#  0.9641967213114754,
#  0.9643137254901961,
#  0.96442996742671,
#  0.9645454545454546,
#  0.9644012944983819,
#  0.964516129032258,
#  0.9646302250803859,
#  0.9647435897435898,
#  0.9648562300319489,
#  0.964968152866242,
#  0.964952380952381,
#  0.9649367088607594,
#  0.9649211356466877,
#  0.9650314465408805,
#  0.965141065830721,
#  0.965125,
#  0.9652336448598131,
#  0.9653416149068323,
#  0.9652012383900929,
#  0.9653086419753086,
#  0.9654153846153846,
#  0.9655214723926381,
#  0.9656269113149847,
#  0.965609756097561,
#  0.9657142857142857,
#  0.9658181818181818,
#  0.9659214501510573,
#  0.9660240963855422,
#  0.9661261261261261,
#  0.9661077844311378,
#  0.9662089552238806,
#  0.9661904761904762,
#  0.9662908011869437,
#  0.9663905325443787,
#  0.9664896755162242,
#  0.9665882352941176,
#  0.9666862170087976,
#  0.9667836257309942,
#  0.9668804664723032,
#  0.9669767441860465,
#  0.9669565217391304,
#  0.9670520231213873,
#  0.9671469740634006,
#  0.9672413793103448,
#  0.9673352435530086,
#  0.9672,
#  0.9671794871794872,
#  0.9672727272727273,
#  0.9673654390934844,
#  0.967457627118644,
#  0.9675492957746479,
#  0.9676404494382023,
#  0.9677310924369747,
#  0.9678212290502793,
#  0.9679108635097493,
#  0.968,
#  0.96797783933518,
#  0.9680662983425414,
#  0.9681542699724518,
#  0.9681318681318681,
#  0.9682191780821918,
#  0.9683060109289617,
#  0.9683923705722071,
#  0.9684782608695652,
#  0.9684552845528456,
#  0.9685405405405405,
#  0.9685175202156334,
#  0.9686021505376344,
#  0.968686327077748,
#  0.968663101604278,
#  0.9687466666666666,
#  0.9688297872340426,
#  0.9688063660477454,
#  0.9687830687830687,
#  0.9688654353562005,
#  0.9689473684210527,
#  0.9689238845144357,
#  0.9690052356020943,
#  0.9689817232375979,
#  0.9690625,
#  0.9691428571428572,
#  0.9692227979274611,
#  0.9693023255813954,
#  0.969381443298969,
#  0.9694601542416452,
#  0.9695384615384616,
#  0.969616368286445,
#  0.9695918367346938,
#  0.9696692111959287,
#  0.9696446700507614,
#  0.9697215189873418,
#  0.9696969696969697,
#  0.9697732997481109,
#  0.969748743718593,
#  0.9698245614035088,
#  0.9698,
#  0.9696758104738155,
#  0.9697512437810946,
#  0.9698263027295285,
#  0.9699009900990099,
#  0.9699753086419753,
#  0.9700492610837439,
#  0.9701228501228502,
#  0.9701960784313726,
#  0.9702689486552567,
#  0.9703414634146341,
#  0.9704136253041362,
#  0.9704854368932039,
#  0.9705569007263922,
#  0.9706280193236715,
#  0.9706987951807229,
#  0.9707692307692307,
#  0.9708393285371703,
#  0.9709090909090909,
#  0.9709785202863962,
#  0.971047619047619,
#  0.971021377672209,
#  0.9710900473933649,
#  0.971063829787234,
#  0.9711320754716981,
#  0.9710117647058824,
#  0.9710798122065728,
#  0.9711475409836066,
#  0.971214953271028,
#  0.9711888111888112,
#  0.9711627906976744,
#  0.9710440835266821,
#  0.9711111111111111,
#  0.9710854503464204,
#  0.9708755760368664,
#  0.9709425287356321,
#  0.9710091743119266,
#  0.9710755148741419,
#  0.9711415525114155,
#  0.9712072892938497,
#  0.9712727272727273,
#  0.9713378684807257,
#  0.9714027149321267,
#  0.9714672686230248,
#  0.9715315315315315,
#  0.9715955056179775,
#  0.9716591928251122,
#  0.9717225950782997,
#  0.9717857142857143,
#  0.9718485523385301,
#  0.9719111111111111,
#  0.9718847006651885,
#  0.971858407079646,
#  0.9719205298013245,
#  0.9719823788546256,
#  0.972043956043956,
#  0.9721052631578947,
#  0.9720787746170678,
#  0.9721397379912664,
#  0.9722004357298475,
#  0.9722608695652174,
#  0.9723210412147505,
#  0.9723809523809523,
#  0.9724406047516199,
#  0.9725,
#  0.9725591397849462,
#  0.9725321888412017,
#  0.9725910064239829,
#  0.9726495726495726,
#  0.9727078891257995,
#  0.9726808510638297,
#  0.9726539278131635,
#  0.9727118644067797,
#  0.972600422832981,
#  0.9726582278481013,
#  0.9727157894736842,
#  0.9727731092436975,
#  0.9728301886792453,
#  0.972887029288703,
#  0.9729436325678497,
#  0.9729166666666667,
#  0.972972972972973,
#  0.9730290456431535,
#  0.9730848861283644,
#  0.9731404958677686,
#  0.9731134020618557,
#  0.9730864197530864,
#  0.9731416837782341,
#  0.9731147540983607,
#  0.9731697341513292,
#  0.9731428571428572,
#  0.9731975560081466,
#  0.9732520325203252,
#  0.9733062880324543,
#  0.9733603238866396,
#  0.9732525252525253,
#  0.9733064516129032,
#  0.9732796780684104,
#  0.9733333333333334,
#  0.9733867735470942,
#  0.97344,
#  0.9734930139720559,
#  0.9735458167330677,
#  0.9735188866799205,
#  0.9734126984126984,
#  0.9734653465346534,
#  0.9735177865612649,
#  0.9735491512041058,
#  0.96,
#  0.96,
#  0.9733333333333334,
#  0.98,
#  0.984,
#  0.9866666666666667,
#  0.9828571428571429,
#  0.98,
#  0.9777777777777777,
#  0.98,
#  0.9781818181818182,
#  0.98,
#  0.9815384615384616,
#  0.9828571428571429,
#  0.984,
#  0.985,
#  0.9835294117647059,
#  0.9844444444444445,
#  0.9852631578947368,
#  0.986,
#  0.9847619047619047,
#  0.9836363636363636,
#  0.9826086956521739,
#  0.9833333333333333,
#  0.984,
#  0.9830769230769231,
#  0.9837037037037037,
#  0.9842857142857143,
#  0.983448275862069,
#  0.9826666666666667,
#  0.983225806451613,
#  0.9825,
#  0.9793939393939394,
#  0.98,
#  0.9805714285714285,
#  0.9811111111111112,
#  0.9816216216216216,
#  0.9821052631578947,
#  0.9815384615384616,
#  0.982,
#  0.9824390243902439,
#  0.9828571428571429,
#  0.9823255813953489,
#  0.9827272727272728,
#  0.9831111111111112,
#  0.9834782608695652,
#  0.9838297872340426,
#  0.9841666666666666,
#  0.9836734693877551,
#  0.984,
#  0.984313725490196,
#  0.9846153846153847,
#  0.9849056603773585,
#  0.9844444444444445,
#  0.9847272727272727,
#  0.985,
#  0.9852631578947368,
#  0.9855172413793103,
#  0.9850847457627119,
#  0.9846666666666667,
#  0.9842622950819672,
#  0.9838709677419355,
#  0.9841269841269841,
#  0.984375,
#  0.9846153846153847,
#  0.9848484848484849,
#  0.9850746268656716,
#  0.9852941176470589,
#  0.984927536231884,
#  0.9851428571428571,
#  0.9853521126760564,
#  0.9855555555555555,
#  0.9857534246575342,
#  0.9854054054054054,
#  0.9850666666666666,
#  0.9852631578947368,
#  0.9849350649350649,
#  0.9851282051282051,
#  0.9853164556962025,
#  0.985,
#  0.9851851851851852,
#  0.984390243902439,
#  0.984578313253012,
#  0.9842857142857143,
#  0.9844705882352941,
#  0.9841860465116279,
#  0.9839080459770115,
#  0.9840909090909091,
#  0.9842696629213483,
#  0.9844444444444445,
#  0.9846153846153847,
#  0.9847826086956522,
#  0.9840860215053764,
#  0.9838297872340426,
#  0.984,
#  0.9841666666666666,
#  0.9835051546391752,
#  0.9836734693877551,
#  0.9838383838383838,
#  0.9836,
#  0.9837623762376237,
#  0.983921568627451,
#  0.9840776699029126,
#  0.9834615384615385,
#  0.9836190476190476,
#  0.9837735849056604,
#  0.9839252336448598,
#  0.9840740740740741,
#  0.9842201834862385,
#  0.9843636363636363,
#  0.9845045045045046,
#  0.9846428571428572,
#  0.984778761061947,
#  0.9849122807017544,
#  0.9850434782608696,
#  0.9848275862068966,
#  0.984957264957265,
#  0.9850847457627119,
#  0.9852100840336134,
#  0.985,
#  0.9851239669421488,
#  0.9852459016393442,
#  0.985040650406504,
#  0.9851612903225806,
#  0.98528,
#  0.9853968253968254,
#  0.9855118110236221,
#  0.985625,
#  0.9857364341085272,
#  0.9855384615384616,
#  0.9853435114503817,
#  0.9854545454545455,
#  0.9849624060150376,
#  0.9850746268656716,
#  0.9845925925925926,
#  0.9847058823529412,
#  0.9848175182481752,
#  0.984927536231884,
#  0.9847482014388489,
#  0.9848571428571429,
#  0.9849645390070922,
#  0.9850704225352113,
#  0.9851748251748251,
#  0.9852777777777778,
#  0.9853793103448276,
#  0.9854794520547945,
#  0.985578231292517,
#  0.9854054054054054,
#  0.9855033557046979,
#  0.9856,
#  0.9856953642384106,
#  0.9857894736842105,
#  0.9858823529411764,
#  0.985974025974026,
#  0.9860645161290322,
#  0.9861538461538462,
#  0.9862420382165605,
#  0.9863291139240506,
#  0.9864150943396226,
#  0.9865,
#  0.986335403726708,
#  0.9864197530864197,
#  0.9865030674846625,
#  0.9865853658536585,
#  0.9864242424242424,
#  0.9865060240963855,
#  0.9865868263473054,
#  0.9866666666666667,
#  0.9867455621301775,
#  0.9868235294117647,
#  0.9869005847953216,
#  0.9867441860465116,
#  0.9868208092485549,
#  0.9868965517241379,
#  0.9869714285714286,
#  0.9870454545454546,
#  0.9868926553672316,
#  0.9867415730337079,
#  0.9868156424581006,
#  0.9866666666666667,
#  0.9867403314917127,
#  0.9863736263736264,
#  0.9862295081967213,
#  0.986304347826087,
#  0.9863783783783784,
#  0.9864516129032258,
#  0.9863101604278075,
#  0.9863829787234043,
#  0.9864550264550265,
#  0.9865263157894737,
#  0.9865968586387435,
#  0.9866666666666667,
#  0.9867357512953367,
#  0.9868041237113402,
#  0.9866666666666667,
#  0.986734693877551,
#  0.9868020304568528,
#  0.9866666666666667,
#  0.9867336683417085,
#  0.9868,
#  0.9866666666666667,
#  0.9865346534653465,
#  0.9866009852216748,
#  0.9866666666666667,
#  0.9863414634146341,
#  0.9864077669902913,
#  0.9864734299516909,
#  0.9865384615384616,
#  0.9866028708133971,
#  0.9866666666666667,
#  0.9867298578199052,
#  0.9867924528301887,
#  0.9868544600938968,
#  0.9869158878504672,
#  0.9869767441860465,
#  0.987037037037037,
#  0.9870967741935484,
#  0.9871559633027523,
#  0.9870319634703196,
#  0.9870909090909091,
#  0.9871493212669683,
#  0.987027027027027,
#  0.987085201793722,
#  0.9871428571428571,
#  0.9872,
#  0.9872566371681416,
#  0.9873127753303965,
#  0.9871929824561404,
#  0.9872489082969432,
#  0.987304347826087,
#  0.9871861471861472,
#  0.9870689655172413,
#  0.9871244635193133,
#  0.9871794871794872,
#  0.9872340425531915,
#  0.9871186440677966,
#  0.9871729957805907,
#  0.9870588235294118,
#  0.9867782426778242,
#  0.9866666666666667,
#  0.9867219917012449,
#  0.9867768595041322,
#  0.9868312757201646,
#  0.9867213114754099,
#  0.9867755102040816,
#  0.9866666666666667,
#  0.9867206477732794,
#  0.9867741935483871,
#  0.9868273092369478,
#  0.98688,
#  0.9869322709163346,
#  0.986984126984127,
#  0.9868774703557313,
#  0.9867716535433071,
#  0.9868235294117647,
#  0.986875,
#  0.9869260700389105,
#  0.9868217054263566,
#  0.9868725868725868,
#  0.9869230769230769,
#  0.9869731800766284,
#  0.9870229007633587,
#  0.9870722433460076,
#  0.9871212121212121,
#  0.9871698113207548,
#  0.987218045112782,
#  0.9872659176029962,
#  0.9871641791044776,
#  0.9872118959107806,
#  0.9871111111111112,
#  0.9870110701107011,
#  0.9870588235294118,
#  0.9871062271062271,
#  0.987007299270073,
#  0.9870545454545454,
#  0.9869565217391304,
#  0.9868592057761733,
#  0.9869064748201439,
#  0.9869534050179212,
#  0.987,
#  0.9870462633451957,
#  0.9870921985815603,
#  0.9869964664310954,
#  0.9870422535211267,
#  0.9870877192982456,
#  0.986993006993007,
#  0.9870383275261324,
#  0.9870833333333333,
#  0.9871280276816609,
#  0.9870344827586207,
#  0.9870790378006873,
#  0.9871232876712329,
#  0.9871672354948805,
#  0.9872108843537415,
#  0.9872542372881355,
#  0.9872972972972973,
#  0.9873400673400673,
#  0.987248322147651,
#  0.9872909698996656,
#  0.9873333333333333,
#  0.987375415282392,
#  0.9874172185430463,
#  0.9874587458745875,
#  0.9875,
#  0.9875409836065574,
#  0.9875816993464053,
#  0.9876221498371336,
#  0.9875324675324675,
#  0.9875728155339806,
#  0.9876129032258064,
#  0.9876527331189711,
#  0.9876923076923076,
#  0.9876038338658147,
#  0.9876433121019108,
#  0.9875555555555555,
#  0.9875949367088608,
#  0.9876340694006309,
#  0.9876729559748427,
#  0.9877115987460815,
#  0.987625,
#  0.9875389408099688,
#  0.9875776397515528,
#  0.9876160990712074,
#  0.9876543209876543,
#  0.9876923076923076,
#  0.9877300613496932,
#  0.9877675840978594,
#  0.9875609756097561,
#  0.9875987841945288,
#  0.9876363636363636,
#  0.9876737160120846,
#  0.9875903614457832,
#  0.9876276276276277,
#  0.9876646706586827,
#  0.9875820895522388,
#  0.9873809523809524,
#  0.9874183976261127,
#  0.9873372781065088,
#  0.9873746312684366,
#  0.9874117647058823,
#  0.9874486803519061,
#  0.9874853801169591,
#  0.9875218658892129,
#  0.9874418604651163,
#  0.9873623188405797,
#  0.9873988439306358,
#  0.9874351585014409,
#  0.9874712643678161,
#  0.9875071633237822,
#  0.9875428571428572,
#  0.9875783475783476,
#  0.9876136363636364,
#  0.9875354107648725,
#  0.9875706214689266,
#  0.9876056338028169,
#  0.9875280898876404,
#  0.987563025210084,
#  0.9875977653631285,
#  0.9876323119777158,
#  0.9874444444444445,
#  0.9873684210526316,
#  0.9874033149171271,
#  0.9874380165289256,
#  0.9873626373626374,
#  0.9872876712328768,
#  0.9873224043715847,
#  0.9873569482288829,
#  0.9872826086956522,
#  0.9872086720867209,
#  0.9872432432432432,
#  0.987277628032345,
#  0.9870967741935484,
#  0.9871313672922252,
#  0.9870588235294118,
#  0.9869866666666667,
#  0.9870212765957447,
#  0.9869496021220159,
#  0.9868783068783069,
#  0.9869129287598944,
#  0.9868421052631579,
#  0.9867716535433071,
#  0.9868062827225131,
#  0.9867362924281984,
#  0.9867708333333334,
#  0.9868051948051948,
#  0.9867357512953367,
#  0.9867700258397932,
#  0.9868041237113402,
#  0.9868380462724936,
#  0.9868717948717949,
#  0.9869053708439898,
#  0.9868367346938776,
#  0.9867684478371501,
#  0.9868020304568528,
#  0.9867341772151899,
#  0.9867676767676767,
#  0.9868010075566751,
#  0.9868341708542714,
#  0.9868671679197994,
#  0.9868,
#  0.9868329177057357,
#  0.9868656716417911,
#  0.9868982630272953,
#  0.9869306930693069,
#  0.9869629629629629,
#  0.9869950738916257,
#  0.987027027027027,
#  0.9869607843137255,
#  0.9869926650366748,
#  0.9869268292682927,
#  0.9869586374695863,
#  0.9869902912621359,
#  0.9870217917675544,
#  0.9870531400966184,
#  0.9870843373493976,
#  0.9870192307692308,
#  0.9870503597122302,
#  0.9870813397129187,
#  0.9871121718377088,
#  0.9871428571428571,
#  0.9871733966745844,
#  0.9872037914691943,
#  0.9872340425531915,
#  0.9872641509433963,
#  0.9872941176470589,
#  0.9871361502347418,
#  0.9871662763466043,
#  0.9871028037383177,
#  0.9871328671328672,
#  0.9871627906976744,
#  0.9871925754060324,
#  0.9871296296296296,
#  0.9871593533487298,
#  0.9870967741935484,
#  0.9871264367816092,
#  0.9871559633027523,
#  0.9870938215102975,
#  0.9871232876712329,
#  0.9871526195899772,
#  0.9871818181818182,
#  0.9871201814058957,
#  0.9871493212669683,
#  0.9870880361173815,
#  0.987027027027027,
#  0.9870561797752809,
#  0.9869955156950673,
#  0.9870246085011186,
#  0.9870535714285714,
#  0.9869933184855234,
#  0.9869333333333333,
#  0.9869623059866962,
#  0.9869911504424779,
#  0.9870198675496689,
#  0.9870484581497797,
#  0.9870769230769231,
#  0.9869298245614035,
#  0.986870897155361,
#  0.9868995633187773,
#  0.9868409586056645,
#  0.9868695652173913,
#  0.9868980477223427,
#  0.9868398268398269,
#  0.9868682505399567,
#  0.9868965517241379,
#  0.9869247311827957,
#  0.9869527896995708,
#  0.9869807280513918,
#  0.9869230769230769,
#  0.9868656716417911,
#  0.9868936170212766,
#  0.9869214437367304,
#  0.9869491525423729,
#  0.9869767441860465,
#  0.9870042194092827,
#  0.9870315789473684,
#  0.9869747899159664,
#  0.9869182389937107,
#  0.9869456066945607,
#  0.986972860125261,
#  0.987,
#  0.9869438669438669,
#  0.9869709543568465,
#  0.9869979296066252,
#  0.9870247933884297,
#  0.9870515463917526,
#  0.9870781893004115,
#  0.9871047227926079,
#  0.9871311475409836,
#  0.9870756646216768,
#  0.9871020408163266,
#  0.9870468431771894,
#  0.9870731707317073,
#  0.9870993914807302,
#  ...]

# %%
len(batch_end_accuracy)
# Out:
# 1014

# %%
# Plot accuracy, loss of the model
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 12))
plt.rcParams.update({'font.size': 14})
plt.plot(batch_end_loss)
plt.title('QCNN - Qnode model: cost')
#plt.ylim([0, 1])
plt.xticks(ticks=np.arange(0, len(batch_end_loss), 20),
           labels=np.arange(0, len(batch_end_loss), 20))
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.legend(['Loss'], loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Benchmarking with measured train data
score_train = model_QCNN_chosen.evaluate(
    X_train[0:num_train], Y_train_onehot[0:num_train], verbose=2)
print("Train loss:", score_train[0])
print("Train accuracy:", score_train[1])
# Out:
# 396/396 - 7015s - loss: 0.0118 - accuracy: 0.9865 - 7015s/epoch - 18s/step
# Train loss: 0.011793718494207758
# Train accuracy: 0.986498223450454

# %%
# Benchmarking with measured test data
score_test = model_QCNN_chosen.evaluate(
    X_test[0:num_test], Y_test_onehot[0:num_test], verbose=2)
print("Test loss:", score_test[0])
print("Test accuracy:", score_test[1])
# Out:
# 67/67 - 1153s - loss: 0.0081 - accuracy: 0.9901 - 1153s/epoch - 17s/step
# Test loss: 0.008134215053485324
# Test accuracy: 0.9900709219858156
